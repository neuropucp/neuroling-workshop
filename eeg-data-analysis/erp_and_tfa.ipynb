# %%
#@title Black Box_(install libraries)
# %%capture
# !pip install pingouin
# !pip install autoreject
# !pip install mne
# !pip install mne_bids
# !pip install mne_icalabel
# !pip install pyprep
# !pip install onnxruntime
# !pip install python-picard
# !pip install ipywidgets
# !apt-get -qq update
# !apt-get -qq install tree

# %%
#@title Import modules

# %%capture
import mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import mne_bids
import autoreject
import seaborn as sns
import pyprep
import ipywidgets
import mne_icalabel

# %%
#@title Black Box_(download after ICLabel)
# %%capture
# !wget "https://drive.usercontent.google.com/download?id=1_GzO8rzA-gvgHWCrqCKMP0lm6KOmkLRn&export=download&confirm" -O aftericlabel.zip
# !unzip -o aftericlabel.zip -d /content/
###Defining variables to read files in BIDS format with mne_bids.
cwd = os.getcwd()
bids_root = os.path.join(cwd, 'afterICLabel')
subjects=['23', '01', '02', '04', '05']
tasks=['default']
paths = mne_bids.find_matching_paths(
                            root=bids_root,
                            subjects=subjects, # Select sub to process
                            tasks=tasks, # Selecting all task by default
                            datatypes='eeg',
                            extensions='.fif' #Antes era .vhdr ¿Por qué cambió? ¡ Yo preguntaría eso !
                            )  #
eeg_labeled = {}
for path in paths:
    raw = mne_bids.read_raw_bids(path, extra_params= {
        'preload': True
        })
    sub= path.subject
    eeg_labeled[sub]=raw.copy()
eeg_labeled

# %% [markdown]
# <h2>Event Related Potentials</h2>
#
# Ya podemos entrar al paradigma de los potenciales relacionados a eventos (ERP), seguramente ya tienen conocimiento de que un potencial relacionado al evento recibe su nombre por el tiempo que pasó desde el evento (el número en milisegundos) y el signo de la amplitud (P para positivo y N para negativo).
# <br>
# La pregunta que podríamos hacer ahora es:
# <br><br>
#
# <center>
#
# *Profe ¿Cómo encuentro un potencial relacionado a eventos en mi señal? ¿Cómo sé dónde está el evento? ¿Desde donde cuento?*
#
# </center>
#
# <br><br>
# Bien, tenemos una primera palabra clave: el **evento**. Empecemos por encontrar dónde estarían guardados los eventos en nuestra señal.
#
# <br>
#
# <h2>Encontrar los eventos</h2>
#
# <br>
#
# Dentro de este archivo original, al estar en formato BIDS, tenemos dos objetos: **los eventos** y las **anotaciones relacionadas a los eventos**.
#
# <br>
#
# Los eventos nos van a decir "aquí sucedió algo". En el archivo EEG tienen la forma de:
# `[tiempo, 0, evento(número)]`
#
# <br>
#
# El número 0 solamente cambia cuando hay eventos que se traslapan, que son tan instantáneos que sucede uno sin que haya terminado el otro.
# <br>
#
# Las anotaciones relacionadas a eventos son información de "qué" sucedió. Normalmente están relacionadas con el id numérico del evento. Con tal que una anotación señala hacia un ID y nos da información de eso.
#
#
# <table>
#   <tr><th colspan="2" align="left">Función: <strong>mne.events_from_annotations</strong></strong>
#   </strong></strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.events_from_annotations.html"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#
#
#   </th></tr>
#
# <br>
# <tr><td>raw</td><td>El archivo de la señal continua. En este caso, está dentro de nuestros diccionarios. </td></tr>
#
# <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
# <td colspan="2">
# Dos objetos, en nuestro caso los llamamos "event_list" y "annotations". El objeto "event_list" es un array/lista que contiene los eventos con la forma [tiempo, 0, evento(número)]. "annotations" es un diccionario que tiene la forma de { "Aquí sucedió algo": evento(número) }. Strings que conducen a los valores que son los eventos.
# </table>

# %%
#Nuestro diccionario de archivos se llama ahora "eeg_labeled". Sigue teniendo como claves los ID y los eeg como valores.

event_list, annotations=mne.events_from_annotations(eeg_labeled['02'])
display(event_list)
print("")
display(annotations)
# Out:
# Used Annotations descriptions: [np.str_('1/WTrigger1/Critical/10/Amb/1/Diseinatzaile hauek esperantza handiz jaitsi dira sariketara/Abs'), np.str_('1/WTrigger1/Critical/102/Amb/1/Bezero haiek denbora luzez ezkutatu dira saltokian/Abs'), np.str_('1/WTrigger1/Critical/106/Amb/1/Kontseilari hauek pandemia egoeragatik arduratu dira prentsaurrean/Abs'), np.str_('1/WTrigger1/Critical/110/Amb/1/Ekologista horiek urduritasun itxuraz ailegatu dira kongresura/Abs'), np.str_('1/WTrigger1/Critical/114/Amb/1/Funtzionario haiek espero bezala atzeratu dira oporretan/Abs'), np.str_('1/WTrigger1/Critical/118/Amb/1/Aktore hauek guztiz burumakur bueltatu dira grabaziotik/Abs'), np.str_('1/WTrigger1/Critical/122/Amb/1/Zinegotzi horiek jaien astean murgildu dira Gasteizen/Abs'), np.str_('1/WTrigger1/Critical/126/Amb/1/Lider haiek urteetan zehar aberastu dira bilkurekin/Abs'), np.str_('1/WTrigger1/Critical/130/Amb/1/Youtuber hauek urtero bezala aztoratu dira partiduarekin/Abs'), np.str_('1/WTrigger1/Critical/134/Amb/1/Musikari horiek bazkal ostean mozkortu dira frontoian/Abs'), np.str_('1/WTrigger1/Critical/138/Amb/1/Futbolzale haiek hamabiak aldera lesionatu dira plazan/Abs'), np.str_('1/WTrigger1/Critical/14/Amb/1/Boxeolari horiek azken unean erori dira lurrera/Abs'), np.str_('1/WTrigger1/Critical/142/Amb/1/Neskatila hauek ziztu bizian koskortu dira futbolean/Abs'), np.str_('1/WTrigger1/Critical/146/Amb/1/Aurkezle horiek telebistako estudioetan desagertu dira iluntzean/Abs'), np.str_('1/WTrigger1/Critical/150/Amb/1/Adiskide haiek modu ezkutuan ahalegindu dira kopiatzen/Abs'), np.str_('1/WTrigger1/Critical/154/Amb/1/Atezain hauek berebiziko energiaz haserretu dira partiduan/Abs'), np.str_('1/WTrigger1/Critical/158/Amb/1/Gerlari horiek urruneko itsasotan hondoratu dira zoritxarrez/Abs'), np.str_('1/WTrigger1/Critical/162/Amb/1/Langile haiek prestutasun handiz gerturartu dira taldera/Abs'), np.str_('1/WTrigger1/Critical/166/Amb/1/Langabe hauek udaletxearen ondoan belaunikatu dira manifestazioan/Abs'), np.str_('1/WTrigger1/Critical/170/Amb/1/Bazkide horiek osteguneko batzordean abstenitu dira giroagatik/Abs'), np.str_('1/WTrigger1/Critical/174/Amb/1/Poeta haiek unibertsitateko aretoan irristatu dira gauean/Abs'), np.str_('1/WTrigger1/Critical/178/Amb/1/Emakume hauek beroaren eraginez zorabiatu dira ibilaldian/Abs'), np.str_('1/WTrigger1/Critical/18/Amb/1/Frantziar haiek ilusio handiz eseri dira jatetxean/Abs'), np.str_('1/WTrigger1/Critical/182/Amb/1/Haur horiek gurasoen laguntzaz iratzartu dira lehiaketarako/Abs'), np.str_('1/WTrigger1/Critical/186/Amb/1/Gizon haiek gauerdi inguruan berragertu dira tabernan/Abs'), np.str_('1/WTrigger1/Critical/190/Amb/1/Biolinista hauek nazioarteko jaialdian desorientatu dira gauean/Abs'), np.str_('1/WTrigger1/Critical/2/Amb/1/Mutil horiek guztiz ezkutuan iragan dira baserritik/Abs'), np.str_('1/WTrigger1/Critical/22/Amb/1/Enpresari hauek atsekabe larrian jabetu dira gatazkaz/Abs'), np.str_('1/WTrigger1/Critical/26/Amb/1/Ikusle horiek aldi berean poztu dira musikarekin/Abs'), np.str_('1/WTrigger1/Critical/30/Amb/1/Mendizale haiek nekearen eraginez oheratu dira mendian/Abs'), np.str_('1/WTrigger1/Critical/34/Amb/1/Ume hauek merendolaren ondoren ahuldu dira eguzkipean/Abs'), np.str_('1/WTrigger1/Critical/38/Amb/1/Jubilatu horiek goizalde partean hoztu dira hirian/Abs'), np.str_('1/WTrigger1/Critical/42/Amb/1/Kirolzale haiek partidua amaitzean zutitu dira azkenean/Abs'), np.str_('1/WTrigger1/Critical/46/Amb/1/Maisu hauek ikastaro horretan nekatu dira asteburuan/Abs'), np.str_('1/WTrigger1/Critical/50/Amb/1/Aktore horiek oso ongi zahartu dira telesailean/Abs'), np.str_('1/WTrigger1/Critical/54/Amb/1/Grebalari haiek manifestazio bukaeran lasaitu dira kalean/Abs'), np.str_('1/WTrigger1/Critical/58/Amb/1/Eskalatzaile hauek Udalaitz igotzen ausartu dira goizean/Abs'), np.str_('1/WTrigger1/Critical/6/Amb/1/Kamioilari haiek lasai asko irten dira errepidera/Abs'), np.str_('1/WTrigger1/Critical/62/Amb/1/Mediku horiek birusaren  ...
# array([[  16254,       0,     336],
#        [  16916,       0,     691],
#        [  17133,       0,    1075],
#        ...,
#        [1103638,       0,    1030],
#        [1103854,       0,    1414],
#        [1104071,       0,    1798]])
# {np.str_('1/WTrigger1/Critical/10/Amb/1/Diseinatzaile hauek esperantza handiz jaitsi dira sariketara/Abs'): 1,
#  np.str_('1/WTrigger1/Critical/102/Amb/1/Bezero haiek denbora luzez ezkutatu dira saltokian/Abs'): 2,
#  np.str_('1/WTrigger1/Critical/106/Amb/1/Kontseilari hauek pandemia egoeragatik arduratu dira prentsaurrean/Abs'): 3,
#  np.str_('1/WTrigger1/Critical/110/Amb/1/Ekologista horiek urduritasun itxuraz ailegatu dira kongresura/Abs'): 4,
#  np.str_('1/WTrigger1/Critical/114/Amb/1/Funtzionario haiek espero bezala atzeratu dira oporretan/Abs'): 5,
#  np.str_('1/WTrigger1/Critical/118/Amb/1/Aktore hauek guztiz burumakur bueltatu dira grabaziotik/Abs'): 6,
#  np.str_('1/WTrigger1/Critical/122/Amb/1/Zinegotzi horiek jaien astean murgildu dira Gasteizen/Abs'): 7,
#  np.str_('1/WTrigger1/Critical/126/Amb/1/Lider haiek urteetan zehar aberastu dira bilkurekin/Abs'): 8,
#  np.str_('1/WTrigger1/Critical/130/Amb/1/Youtuber hauek urtero bezala aztoratu dira partiduarekin/Abs'): 9,
#  np.str_('1/WTrigger1/Critical/134/Amb/1/Musikari horiek bazkal ostean mozkortu dira frontoian/Abs'): 10,
#  np.str_('1/WTrigger1/Critical/138/Amb/1/Futbolzale haiek hamabiak aldera lesionatu dira plazan/Abs'): 11,
#  np.str_('1/WTrigger1/Critical/14/Amb/1/Boxeolari horiek azken unean erori dira lurrera/Abs'): 12,
#  np.str_('1/WTrigger1/Critical/142/Amb/1/Neskatila hauek ziztu bizian koskortu dira futbolean/Abs'): 13,
#  np.str_('1/WTrigger1/Critical/146/Amb/1/Aurkezle horiek telebistako estudioetan desagertu dira iluntzean/Abs'): 14,
#  np.str_('1/WTrigger1/Critical/150/Amb/1/Adiskide haiek modu ezkutuan ahalegindu dira kopiatzen/Abs'): 15,
#  np.str_('1/WTrigger1/Critical/154/Amb/1/Atezain hauek berebiziko energiaz haserretu dira partiduan/Abs'): 16,
#  np.str_('1/WTrigger1/Critical/158/Amb/1/Gerlari horiek urruneko itsasotan hondoratu dira zoritxarrez/Abs'): 17,
#  np.str_('1/WTrigger1/Critical/162/Amb/1/Langile haiek prestutasun handiz gerturartu dira taldera/Abs'): 18,
#  np.str_('1/WTrigger1/Critical/166/Amb/1/Langabe hauek udaletxearen ondoan belaunikatu dira manifestazioan/Abs'): 19,
#  np.str_('1/WTrigger1/Critical/170/Amb/1/Bazkide horiek osteguneko batzordean abstenitu dira giroagatik/Abs'): 20,
#  np.str_('1/WTrigger1/Critical/174/Amb/1/Poeta haiek unibertsitateko aretoan irristatu dira gauean/Abs'): 21,
#  np.str_('1/WTrigger1/Critical/178/Amb/1/Emakume hauek beroaren eraginez zorabiatu dira ibilaldian/Abs'): 22,
#  np.str_('1/WTrigger1/Critical/18/Amb/1/Frantziar haiek ilusio handiz eseri dira jatetxean/Abs'): 23,
#  np.str_('1/WTrigger1/Critical/182/Amb/1/Haur horiek gurasoen laguntzaz iratzartu dira lehiaketarako/Abs'): 24,
#  np.str_('1/WTrigger1/Critical/186/Amb/1/Gizon haiek gauerdi inguruan berragertu dira tabernan/Abs'): 25,
#  np.str_('1/WTrigger1/Critical/190/Amb/1/Biolinista hauek nazioarteko jaialdian desorientatu dira gauean/Abs'): 26,
#  np.str_('1/WTrigger1/Critical/2/Amb/1/Mutil horiek guztiz ezkutuan iragan dira baserritik/Abs'): 27,
#  np.str_('1/WTrigger1/Critical/22/Amb/1/Enpresari hauek atsekabe larrian jabetu dira gatazkaz/Abs'): 28,
#  np.str_('1/WTrigger1/Critical/26/Amb/1/Ikusle horiek aldi berean poztu dira musikarekin/Abs'): 29,
#  np.str_('1/WTrigger1/Critical/30/Amb/1/Mendizale haiek nekearen eraginez oheratu dira mendian/Abs'): 30,
#  np.str_('1/WTrigger1/Critical/34/Amb/1/Ume hauek merendolaren ondoren ahuldu dira eguzkipean/Abs'): 31,
#  np.str_('1/WTrigger1/Critical/38/Amb/1/Jubilatu horiek goizalde partean hoztu dira hirian/Abs'): 32,
#  np.str_('1/WTrigger1/Critical/42/Amb/1/Kirolzale haiek partidua amaitzean zutitu dira azkenean/Abs'): 33,
#  np.str_('1/WTrigger1/Critical/46/Amb/1/Maisu hauek ikastaro horretan nekatu dira asteburuan/Abs'): 34,
#  np.str_('1/WTrigger1/Critical/50/Amb/1/Aktore horiek oso ongi zahartu dira telesailean/Abs'): 35,
#  np.str_('1/WTrigger1/Critical/54/Amb/1/Grebalari haiek manifestazio bukaeran lasaitu dira kalean/Abs'): 36,
#  np.str_('1/WTrigger1/Critical/58/Amb/1/Eskalatzaile hauek Udalaitz igotzen ausartu dira goizean/Abs'): 37,
#  np.str_('1/WTrigger1/Critical/6/Amb/1/Kamioilari haiek lasai asko irten dira errepidera/Abs'): 38,
#  np.str_('1/WTrigger1/Critical/62/Amb/1/Mediku horiek birusaren ondorioz kezkatu dira lanean/Abs'): 39,
#  np.str_('1/WTrigger1/Critical/66/Amb/1/Emakume haiek klinikako medikuekin harrotu dira gaur/Abs'): 40,
#  np.str_('1/WTrigger1/Critical/70/Amb/1/Lehiakide hauek asko kostata altxatu dira Amazonasen/Abs'): 41,
#  np.str_('1/WTrigger1/Critical/74/Amb/1/Eskale horiek egoeraren ondorioz larritu dira zoritxarrez/Abs'): 42,
#  np.str_('1/WTrigger1/Critical/78/Amb/1/Senegaldar haiek abadearen hitzekin lotsatu dira mezan/Abs'): 43,
#  np.str_('1/WTrigger1/Critical/82/Amb/1/Igerilari hauek lehiaketaren ostean gaixotu dira hondartzan/Abs'): 44,
#  np.str_('1/WTrigger1/Critical/86/Amb/1/Gimnasta horiek poliki poliki lokartu dira ilunabarrean/Abs'): 45,
#  np.str_('1/WTrigger1/Critical/90/Amb/1/Ministro haiek manifestazioa ikustean kikildu dira hotelean/Abs'): 46,
#  np.str_('1/WTrigger1/Critical/94/Amb/1/Famatu hauek istripuaren eraginez banandu dira azkenean/Abs'): 47,
#  np.str_('1/WTrigger1/Critical/98/Amb/1/Astronauta horiek ordu luzez hurbildu dira Ilargirantz/Abs'): 48,
#  np.str_('1/WTrigger2/Critical/1/Amb/2/Aizkolari hauek gaur goizean jokatu dute Bilbon/Erg'): 49,
#  np.str_('1/WTrigger2/Filler/1/Unamb/-/Abeltzain horrek diru mordoa zor du nan/Erg'): 50,
#  np.str_('10/WTrigger2/Critical/10/Amb/1/Diseinatzaile hauek esperantza handiz jaitsi dira sariketara/Abs'): 51,
#  np.str_('10/WTrigger2/Filler/10/Unamb/-/Taberna horrek zarata ozena egin du nan/Erg'): 52,
#  np.str_('100/WTrigger2/Critical/100/Unamb/3/Abokatu hau hamaikak aldera hurbildu da epaitegira/Abs'): 53,
#  np.str_('100/WTrigger2/Filler/100/-/-/Aspaldi batean amonak asko josten zuen nan/Erg'): 54,
#  np.str_('101/WTrigger2/Critical/101/Amb/2/Sorgin horiek hiru orduz pentsatu dute etxolan/Erg'): 55,
#  np.str_('101/WTrigger2/Filler/101/-/-/Inola ere ez dute oparituko baloia nan/Erg'): 56,
#  np.str_('102/WTrigger2/Critical/102/Amb/1/Bezero haiek denbora luzez ezkutatu dira saltokian/Abs'): 57,
#  np.str_('102/WTrigger2/Filler/102/-/-/Uztail erdialdean lagunak etxea berriztu zuen nan/Erg'): 58,
#  np.str_('103/WTrigger2/Critical/103/Unamb/4/Bitartekari honek mehatxuen ondorioz deklaratu du etxetik/Erg'): 59,
#  np.str_('103/WTrigger2/Filler/103/-/-/Iazko abenduan iritsi zen ikasle berria herrira/Abs'): 60,
#  np.str_('104/WTrigger2/Critical/104/Unamb/3/Atleta hori oraintxe bertan ezkutatu da harmailetan/Abs'): 61,
#  np.str_('104/WTrigger2/Filler/104/-/-/Sekulako zalapartarekin sartu da etxera mozkor hori/Abs'): 62,
#  np.str_('105/WTrigger2/Critical/105/Amb/2/Aita haiek seme-alaben kustodiagatik argudiatu dute gaur/Erg'): 63,
#  np.str_('105/WTrigger2/Filler/105/-/-/Sutondoan eseri da zure osaba Nicolas nan/Abs'): 64,
#  np.str_('106/WTrigger2/Critical/106/Amb/1/Kontseilari hauek pandemia egoeragatik arduratu dira prentsaurrean/Abs'): 65,
#  np.str_('106/WTrigger2/Filler/106/-/-/Frontoian izan da aurtengo herri bazkaria Lizarran/Abs'): 66,
#  np.str_('107/WTrigger2/Critical/107/Unamb/4/Gitarrista horrek managerrekin batera begiratu du publikorantz/Erg'): 67,
#  np.str_('107/WTrigger2/Filler/107/-/-/Hirugarren aldiz ezkondu da gizon hori aurten/Abs'): 68,
#  np.str_('108/WTrigger2/Critical/108/Unamb/3/Tutore hura denbora luzez arduratu da arazoaz/Abs'): 69,
#  np.str_('108/WTrigger2/Filler/108/-/-/Modu baldarrean erori nintzen lurrera atzo nan/Abs'): 70,
#  np.str_('109/WTrigger2/Critical/109/Amb/2/Testigu hauek oso bizkor deklaratu dute epaitegian/Erg'): 71,
#  np.str_('109/WTrigger2/Filler/109/Unamb/-/Emakumeek lan ikarragarria egin dute nan nan/Erg'): 72,
#  np.str_('11/WTrigger2/Critical/11/Unamb/4/Kirolari horrek luzaketen ostean jokatu du kantxan/Erg'): 73,
#  np.str_('11/WTrigger2/Filler/11/Unamb/-/Zaintzaile hark etxe osoa garbitu du nan/Erg'): 74,
#  np.str_('110/WTrigger2/Critical/110/Amb/1/Ekologista horiek urduritasun itxuraz ailegatu dira kongresura/Abs'): 75,
#  np.str_('110/WTrigger2/Filler/110/Unamb/-/Txiroek laguntza gehiago behar dituzte errentak ordaintzeko/Erg'): 76,
#  np.str_('111/WTrigger2/Critical/111/Unamb/4/Ekintzaile hark kezka handiz pentsatu du bileran/Erg'): 77,
#  np.str_('111/WTrigger2/Filler/111/Unamb/-/Festek herri osoa alaitu dute aurtengo udan/Erg'): 78,
#  np.str_('112/WTrigger2/Critical/112/Unamb/3/Alkate hau harrokeria handiz ailegatu da udaletxera/Abs'): 79,
#  np.str_('112/WTrigger2/Filler/112/Unamb/-/Hartzek ez ohi dute zomorrorik jaten nan/Erg'): 80,
#  np.str_('113/WTrigger2/Critical/113/Amb/2/Jakintsu horiek denbora luzez predikatu dute bidaian/Erg'): 81,
#  np.str_('113/WTrigger2/Filler/113/Unamb/-/Otsoek taldean ehizatzen dituzte ardiak gehienetan nan/Erg'): 82,
#  np.str_('114/WTrigger2/Critical/114/Amb/1/Funtzionario haiek espero bezala atzeratu dira oporretan/Abs'): 83,
#  np.str_('114/WTrigger2/Filler/114/Unamb/-/Lapurrek ez zuten arrastorik utzi etxean nan/Erg'): 84,
#  np.str_('115/WTrigger2/Critical/115/Unamb/4/Ikasle honek ordu erdiz antzeztu du jolastorduan/Erg'): 85,
#  np.str_('115/WTrigger2/Filler/115/Unamb/-/Birkiek jende asko ezagutu dute beti nan/Erg'): 86,
#  np.str_('116/WTrigger2/Critical/116/Unamb/3/Ordezkari hori istiluen ondorioz atzeratu da batzordean/Abs'): 87,
#  np.str_('116/WTrigger2/Filler/116/Amb/-/Atsoak bosgarren aldian lortu zuen laguna konbentzitzea/Erg'): 88,
#  np.str_('117/WTrigger2/Critical/117/Amb/2/Hippy haiek diru gutxirekin bidaiatu dute Ameriketatik/Erg'): 89,
#  np.str_('117/WTrigger2/Filler/117/Amb/-/Txakurrak zaunka pasa zuen arratsalde osoa atzo/Erg'): 90,
#  np.str_('118/WTrigger2/Critical/118/Amb/1/Aktore hauek guztiz burumakur bueltatu dira grabaziotik/Abs'): 91,
#  np.str_('118/WTrigger2/Filler/118/Amb/-/Postariak motxila bete betea zeraman bizikletan zihoala/Erg'): 92,
#  np.str_('119/WTrigger2/Critical/119/Unamb/4/Diruzain horrek oso damututa dimititu du kargutik/Erg'): 93,
#  np.str_('119/WTrigger2/Filler/119/Amb/-/Fakirrak ikuskizun polita eskaini zuen zirkuan nan/Erg'): 94,
#  np.str_('12/WTrigger2/Critical/12/Unamb/3/Diputatu hura urte luzez jaitsi da herritarrengana/Abs'): 95,
#  np.str_('12/WTrigger2/Filler/12/Unamb/-/Fakir honek orratz luzea irentsi du nan/Erg'): 96,
#  np.str_('120/WTrigger2/Critical/120/Unamb/3/Apezpiku hura neke aurpegiaz bueltatu da Erromatik/Abs'): 97,
#  np.str_('120/WTrigger2/Filler/120/Amb/-/Produktoreak ez zuen begi onez ikusi pelikularen/Erg'): 98,
#  np.str_('121/WTrigger2/Critical/121/Amb/2/Haur hauek oporraldi garaian antzeztu dute uztailean/Erg'): 99,
#  np.str_('121/WTrigger2/Filler/121/Amb/-/Armiarmak umea izutu du baserrian nan nan/Erg'): 100,
#  np.str_('122/WTrigger2/Critical/122/Amb/1/Zinegotzi horiek jaien astean murgildu dira Gasteizen/Abs'): 101,
#  np.str_('122/WTrigger2/Filler/122/Amb/-/Azeriak baserritarraren bi oilo jan ditu nan/Erg'): 102,
#  np.str_('123/WTrigger2/Critical/123/Unamb/4/Misiolari hark indigenen artean predikatu du Hondurasen/Erg'): 103,
#  np.str_('123/WTrigger2/Filler/123/Amb/-/Jaioberriak oso azkar nekatzen dira egunean zehar/Abs'): 104,
#  np.str_('124/WTrigger2/Critical/124/Unamb/3/Turista hau Mexikon barrena murgildu da abuztuan/Abs'): 105,
#  np.str_('124/WTrigger2/Filler/124/Amb/-/Matematikariak ez dira iritsi ekuazio hori ebaztera/Abs'): 106,
#  np.str_('125/WTrigger2/Filler/125/Amb/-/Ospakizunak bertan behera geratu dira tamalez nan/Abs'): 107,
#  np.str_('126/WTrigger2/Critical/126/Amb/1/Lider haiek urteetan zehar aberastu dira bilkurekin/Abs'): 108,
#  np.str_('126/WTrigger2/Filler/126/Amb/-/Zirujauak etorri zaizkigu operazioaren berri ematera nan/Abs'): 109,
#  np.str_('127/WTrigger2/Critical/127/Unamb/4/Farmazialari honek txertoei esker bidaiatu du Alemaniara/Erg'): 110,
#  np.str_('127/WTrigger2/Filler/127/Amb/-/Artzainak mendian zehar ibili dira txakurraren bila/Abs'): 111,
#  np.str_('128/WTrigger2/Critical/128/Unamb/3/Umorista hori managerrari esker aberastu da pelikulekin/Abs'): 112,
#  np.str_('128/WTrigger2/Filler/128/Amb/-/Influencerrak oso aberats egin dira azken urtean/Abs'): 113,
#  np.str_('129/WTrigger2/Critical/129/Amb/2/Jokalari haiek hasi orduko izerditu dute zelaian/Erg'): 114,
#  np.str_('129/WTrigger2/Filler/129/Amb/-/Paperak beharko ditugu arratsaldeko eskulana ondo egiteko/Abs'): 115,
#  np.str_('13/WTrigger2/Critical/13/Amb/2/Ikasle hauek eguerdi inguruan bozkatu dute ikasgelan/Erg'): 116,
#  np.str_('13/WTrigger2/Filler/13/Unamb/-/Lotsagabe horrek irain larria bota du nan/Erg'): 117,
#  np.str_('130/WTrigger2/Critical/130/Amb/1/Youtuber hauek urtero bezala aztoratu dira partiduarekin/Abs'): 118,
#  np.str_('130/WTrigger2/Filler/130/Unamb/-/Kakahuetea trabatu zaio eztarrian gizonari nan nan/Abs'): 119,
#  np.str_('131/WTrigger2/Critical/131/Unamb/4/Tronpetista horrek zuzendaria sartzean entsaiatu du arratsaldean/Erg'): 120,
#  np.str_('131/WTrigger2/Filler/131/Unamb/-/Dokumentua prest dago jada irakurri nahi baduzu/Abs'): 121,
#  np.str_('132/WTrigger2/Critical/132/Unamb/3/Sukaldari hura ardoa edanda aztoratu da elkartean/Abs'): 122,
#  np.str_('132/WTrigger2/Filler/132/Unamb/-/Eulia paretaren kontra zanpatu da nan nan/Abs'): 123,
#  np.str_('133/WTrigger2/Critical/133/Amb/2/Soprano hauek hilero hilero kotizatu dute aurten/Erg'): 124,
#  np.str_('133/WTrigger2/Filler/133/Unamb/-/Nerea pozik eta alai joan da etxera/Abs'): 125,
#  np.str_('134/WTrigger2/Critical/134/Amb/1/Musikari horiek bazkal ostean mozkortu dira frontoian/Abs'): 126,
#  np.str_('134/WTrigger2/Filler/134/Unamb/-/Igerilaria zeharo nekatuta iritsi da helmugara lasterketan/Abs'): 127,
#  np.str_('135/WTrigger2/Critical/135/Unamb/4/Tabernari hark herriko festetan kozinatu du gazteentzako/Erg'): 128,
#  np.str_('135/WTrigger2/Filler/135/Unamb/-/Maria ez dago etxean momentu honetan nan/Abs'): 129,
#  np.str_('136/WTrigger2/Critical/136/Unamb/3/Nerabe hau BBK jaialdian mozkortu da horrenbeste/Abs'): 130,
#  np.str_('136/WTrigger2/Filler/136/Unamb/-/Josebe oso harro dago bere amonaz nan/Abs'): 131,
#  np.str_('137/WTrigger2/Critical/137/Amb/2/Dantzari horiek Arriagako eszenatokian entsaiatu dute goizean/Erg'): 132,
#  np.str_('137/WTrigger2/Filler/137/-/-/Urteetan zehar egin dugu kontzertu hau Andramari/Erg'): 133,
#  np.str_('138/WTrigger2/Critical/138/Amb/1/Futbolzale haiek hamabiak aldera lesionatu dira plazan/Abs'): 134,
#  np.str_('138/WTrigger2/Filler/138/-/-/Larunbat arratsaldean joan ginen amama bisitatzera nan/Abs'): 135,
#  np.str_('139/WTrigger2/Critical/139/Unamb/4/Korrikalari honek eguzki galdatan izerditu du mendian/Erg'): 136,
#  np.str_('139/WTrigger2/Filler/139/-/-/Etzi goizean ikusi zintudan kalean lagunarekin nan/Erg'): 137,
#  np.str_('14/WTrigger2/Critical/14/Amb/1/Boxeolari horiek azken unean erori dira lurrera/Abs'): 138,
#  np.str_('14/WTrigger2/Filler/14/Unamb/-/Mozkor hark edalontzi bat hautsi du nan/Erg'): 139,
#  np.str_('140/WTrigger2/Critical/140/Unamb/3/Harakin hori bere jardunagatik lesionatu da oraingoan/Abs'): 140,
#  np.str_('140/WTrigger2/Filler/140/-/-/Negu osoan egon da Formigaleko eski estazioa/Abs'): 141,
#  np.str_('141/WTrigger2/Critical/141/Amb/2/Mutiko haiek amonaren alboan kozinatu dute umetatik/Erg'): 142,
#  np.str_('141/WTrigger2/Filler/141/-/-/Abuztu partean joaten gara normalean Zumaiara oporretan/Abs'): 143,
#  np.str_('142/WTrigger2/Critical/142/Amb/1/Neskatila hauek ziztu bizian koskortu dira futbolean/Abs'): 144,
#  np.str_('142/WTrigger2/Filler/142/-/-/Gauerdi inguruan sartu zen lapurra etxera nan/Abs'): 145,
#  np.str_('143/WTrigger2/Critical/143/Unamb/4/Gaztetxo horrek konturatu gabe kotizatu du lanean/Erg'): 146,
#  np.str_('143/WTrigger2/Filler/143/-/-/Herenegun eguzkia izan genuen egun osoan zehar/Erg'): 147,
#  np.str_('144/WTrigger2/Critical/144/Unamb/3/Ume hura musikariz inguratuta koskortu da herrian/Abs'): 148,
#  np.str_('144/WTrigger2/Filler/144/-/-/Bihar bukatuko ditut azterketak behingoz nan nan/Abs'): 149,
#  np.str_('145/WTrigger2/Critical/145/Amb/2/Militar hauek Kubako gerrillan borrokatu dute aurten/Erg'): 150,
#  np.str_('145/WTrigger2/Filler/145/-/-/Goizean goiz esnatu gara lasterketan parte hartzeko/Abs'): 151,
#  np.str_('146/WTrigger2/Critical/146/Amb/1/Aurkezle horiek telebistako estudioetan desagertu dira iluntzean/Abs'): 152,
#  np.str_('146/WTrigger2/Filler/146/-/-/Zergatik etorri zen ere ez daki gizonak/Abs'): 153,
#  np.str_('147/WTrigger2/Critical/147/Unamb/4/Lagun hark besteen ezkutuan xuxurlatu du bazkarian/Erg'): 154,
#  np.str_('147/WTrigger2/Filler/147/-/-/Zergatik zegoen negarrez galdetu nion parkeko neskatoari/Abs'): 155,
#  np.str_('148/WTrigger2/Critical/148/Unamb/3/Txirrindulari hau hiru egunez desagertu da Pirinioetan/Abs'): 156,
#  np.str_('148/WTrigger2/Filler/148/-/-/Nolatan agertu zaren jakin nahi nuke nan/Abs'): 157,
#  np.str_('149/WTrigger2/Critical/149/Amb/2/Tertuliakide horiek gogo biziz eztabaidatu dute laguntzez/Erg'): 158,
#  np.str_('149/WTrigger2/Filler/149/-/-/Zoritxarrez amona erresidentziako eskaileretan erori da arratsaldean/Abs'): 159,
#  np.str_('15/WTrigger2/Critical/15/Unamb/4/Pirata hark ardoz lepo iraun du itsasoan/Erg'): 160,
#  np.str_('15/WTrigger2/Filler/15/Unamb/-/Gamelu honek bisitaria gogor kolpatu du nan/Erg'): 161,
#  np.str_('150/WTrigger2/Critical/150/Amb/1/Adiskide haiek modu ezkutuan ahalegindu dira kopiatzen/Abs'): 162,
#  np.str_('150/WTrigger2/Filler/150/-/-/Ustekabean agertu ziren guardia zibilak bere etxean/Abs'): 163,
#  np.str_('151/WTrigger2/Critical/151/Unamb/4/Pertikalari honek kemen handiz entrenatu du hobetzeko/Erg'): 164,
#  np.str_('151/WTrigger2/Filler/151/-/-/Bapatean hasi zen elurra egun hartan nan/Abs'): 165,
#  np.str_('152/WTrigger2/Critical/152/Unamb/3/Palestinar hori urteetan zehar ahalegindu da liberatzen/Abs'): 166,
#  np.str_('152/WTrigger2/Filler/152/-/-/Zorionez ez du inork errepikatu gure klasean/Erg'): 167,
#  np.str_('153/WTrigger2/Critical/153/Amb/2/Boluntario haiek euren artean xuxurlatu dute bileran/Erg'): 168,
#  np.str_('153/WTrigger2/Filler/153/-/-/Egundoko indarrez jo dio lapurrak diruzainari nan/Erg'): 169,
#  np.str_('154/WTrigger2/Critical/154/Amb/1/Atezain hauek berebiziko energiaz haserretu dira partiduan/Abs'): 170,
#  np.str_('154/WTrigger2/Filler/154/-/-/Eguerdiko ordubietan eraman dut haurra eskolara nan/Erg'): 171,
#  np.str_('155/WTrigger2/Critical/155/Unamb/4/Detektibe horrek tarte luzez borrokatu du poliziarekin/Erg'): 172,
#  np.str_('155/WTrigger2/Filler/155/-/-/Faborea eskertzeko bonboiak oparitu dizkiot irakasleari nan/Erg'): 173,
#  np.str_('156/WTrigger2/Critical/156/Unamb/3/Kazetari hura telefono deian haserretu da editoreekin/Abs'): 174,
#  np.str_('156/WTrigger2/Filler/156/-/-/Esfortzu oso txikiarekin iritsi da helmugara hori/Abs'): 175,
#  np.str_('157/WTrigger2/Critical/157/Amb/2/Arraunlari hauek itsaso zabalean entrenatu dute goizaldean/Erg'): 176,
#  np.str_('157/WTrigger2/Filler/157/-/-/Kontzertuaren etenean aldatu da jantziz sopranoa nan/Abs'): 177,
#  np.str_('158/WTrigger2/Critical/158/Amb/1/Gerlari horiek urruneko itsasotan hondoratu dira zoritxarrez/Abs'): 178,
#  np.str_('158/WTrigger2/Filler/158/-/-/Etxea apaintzeko ekarri zuen amonak kuadro zaharra/Erg'): 179,
#  np.str_('159/WTrigger2/Critical/159/Unamb/4/Alargun hark galeraren saminaz eztabaidatu du tanatorioan/Erg'): 180,
#  np.str_('159/WTrigger2/Filler/159/-/-/Hiltzeraino egin zuen gose greba militante turkiarrak/Erg'): 181,
#  np.str_('16/WTrigger2/Critical/16/Unamb/3/Gazte hau kanpuseko aretoan erori da goizean/Abs'): 182,
#  np.str_('16/WTrigger2/Filler/16/Unamb/-/Maizter horrek errenta erdia ordaindu du nan/Erg'): 183,
#  np.str_('160/WTrigger2/Critical/160/Unamb/3/Bidaiari hau oso leunki hondoratu da itsasoan/Abs'): 184,
#  np.str_('160/WTrigger2/Filler/160/-/-/Bere aita alaitzeko ekarri zuen oparia etxera/Erg'): 185,
#  np.str_('161/WTrigger2/Critical/161/Amb/2/Foruzain horiek kuriositate handiz hausnartu dute istripuaz/Erg'): 186,
#  np.str_('161/WTrigger2/Filler/161/-/-/Urtero urtero irakasleek azterketak zuzentzen dituzte garai/Erg'): 187,
#  np.str_('162/WTrigger2/Critical/162/Amb/1/Langile haiek prestutasun handiz gerturartu dira taldera/Abs'): 188,
#  np.str_('162/WTrigger2/Filler/162/-/-/Kontu handiz ekarri behar dituzu arrautzak oilotegitik/Erg'): 189,
#  np.str_('163/WTrigger2/Critical/163/Unamb/4/Bizilagun honek kaleko zaratengatik protestatu du balkoian/Erg'): 190,
#  np.str_('163/WTrigger2/Filler/163/-/-/Oso bortizki erantzun dio epaileak akusatuari nan/Erg'): 191,
#  np.str_('164/WTrigger2/Critical/164/Unamb/3/Pilotu hori hegazkin bidaian gerturartu da Donostiara/Abs'): 192,
#  np.str_('164/WTrigger2/Filler/164/-/-/Hondartzaren ondoan zerbeza bat hartu dugu arratsaldean/Erg'): 193,
#  np.str_('165/WTrigger2/Critical/165/Amb/2/Masajista haiek entrenatzailearen esanetara funtzionatu dute zelaian/Erg'): 194,
#  np.str_('165/WTrigger2/Filler/165/-/-/Kontseiluaren idazkari nagusia galdu egin zen hirian/Abs'): 195,
#  np.str_('166/WTrigger2/Critical/166/Amb/1/Langabe hauek udaletxearen ondoan belaunikatu dira manifestazioan/Abs'): 196,
#  np.str_('166/WTrigger2/Filler/166/-/-/Euskalgintzako eragileek manifestazio bateratua deitu dute Iruñean/Erg'): 197,
#  np.str_('167/WTrigger2/Critical/167/Unamb/4/Fededun horrek apaizaren hitzekin disfrutatu du mezetan/Erg'): 198,
#  np.str_('167/WTrigger2/Filler/167/-/-/Zuzendariaren erruz izan dira irakasle aldaketak nan/Abs'): 199,
#  np.str_('168/WTrigger2/Critical/168/Unamb/3/Mandatari hura elizaren atarian belaunikatu da goizean/Abs'): 200,
#  np.str_('168/WTrigger2/Filler/168/-/-/Errektorearen senarra nire herrikoa da nan nan/Abs'): 201,
#  np.str_('169/WTrigger2/Critical/169/Amb/2/Intsumiso hauek igandeko hauteskundeetan protestatu dute berriro/Erg'): 202,
#  np.str_('169/WTrigger2/Filler/169/-/-/Ordenagailuko programez hitz egin du adituak irratian/Erg'): 203,
#  np.str_('17/WTrigger2/Critical/17/Amb/2/Manifestari horiek gogoz kontra etsi dute bileran/Erg'): 204,
#  np.str_('17/WTrigger2/Filler/17/Unamb/-/Amona hark hiru goxoki oparitu du nan/Erg'): 205,
#  np.str_('170/WTrigger2/Critical/170/Amb/1/Bazkide horiek osteguneko batzordean abstenitu dira giroagatik/Abs'): 206,
#  np.str_('170/WTrigger2/Filler/170/-/-/Ikasleen izenean etorri zen bilerara ordezkari hau/Abs'): 207,
#  np.str_('171/WTrigger2/Critical/171/Unamb/4/Filosofo hark konbentzimendu osoz hausnartu du hausteskundeetaz/Erg'): 208,
#  np.str_('171/WTrigger2/Filler/171/-/-/Ahuntzen esneak onura asko omen ditu osasunarentzat/Erg'): 209,
#  np.str_('172/WTrigger2/Critical/172/Unamb/3/Lankide hau taldearekin bat abstenitu da batzordean/Abs'): 210,
#  np.str_('172/WTrigger2/Filler/172/-/-/Herriez eta hiriez egin du berba idazleak/Erg'): 211,
#  np.str_('173/WTrigger2/Critical/173/Amb/2/Erretiratu horiek goizeko ibilaldian disfrutatu dute lakuaz/Erg'): 212,
#  np.str_('173/WTrigger2/Filler/173/-/-/Zuberoatik etorri dira turista hauek nan nan/Abs'): 213,
#  np.str_('174/WTrigger2/Critical/174/Amb/1/Poeta haiek unibertsitateko aretoan irristatu dira gauean/Abs'): 214,
#  np.str_('174/WTrigger2/Filler/174/-/-/Maskararik gabe etorri da pertsona hori ospitalera/Abs'): 215,
#  np.str_('175/WTrigger2/Critical/175/Unamb/4/Patinatzaile honek lehiaketan gaizki funtzionatu du tamalez/Erg'): 216,
#  np.str_('175/WTrigger2/Filler/175/-/-/Europako makroetxalderik handiena Euskal Herrian kokatzen da/Abs'): 217,
#  np.str_('176/WTrigger2/Critical/176/Unamb/3/Modelo hori takoidun oinetakoekin irristatu da agerraldian/Abs'): 218,
#  np.str_('176/WTrigger2/Filler/176/-/-/Presoen gizarteratzea sustauko du Eusko Jaurlaritzak erakunde/Erg'): 219,
#  np.str_('177/WTrigger2/Critical/177/Amb/2/Ikertzaile haiek itsasoko espedizioan kolaboratu dute proiektuan/Erg'): 220,
#  np.str_('177/WTrigger2/Filler/177/-/-/Arrautzen kolorea aldatzen da animaliaren arabera nan/Abs'): 221,
#  np.str_('178/WTrigger2/Critical/178/Amb/1/Emakume hauek beroaren eraginez zorabiatu dira ibilaldian/Abs'): 222,
#  np.str_('178/WTrigger2/Filler/178/-/-/Ekonomiaren hazkundea espero da datorren urterako nan/Abs'): 223,
#  np.str_('179/WTrigger2/Critical/179/Unamb/4/Neska horrek eguzki izpiekin distiratu du eguerdian/Erg'): 224,
#  np.str_('179/WTrigger2/Filler/179/-/-/Ideiaz aldatzen duzunean deituko didazu nan nan/Erg'): 225,
#  np.str_('18/WTrigger2/Critical/18/Amb/1/Frantziar haiek ilusio handiz eseri dira jatetxean/Abs'): 226,
#  np.str_('18/WTrigger2/Filler/18/Unamb/-/Maskara honek min handia eragin du nan/Erg'): 227,
#  np.str_('180/WTrigger2/Critical/180/Unamb/3/Mutil hura azkenaldian gehiegi zorabiatu da tamalez/Abs'): 228,
#  np.str_('180/WTrigger2/Filler/180/-/-/Errusiako hiriburua Mosku da gaur egun nan/Abs'): 229,
#  np.str_('181/WTrigger2/Critical/181/Amb/2/Zauritu hauek ospitaleko logelan deskantsatu dute gaur/Erg'): 230,
#  np.str_('181/WTrigger2/Filler/181/-/-/Kontzertuko bigarren orduan jo dute abesti hori/Erg'): 231,
#  np.str_('182/WTrigger2/Critical/182/Amb/1/Haur horiek gurasoen laguntzaz iratzartu dira lehiaketarako/Abs'): 232,
#  np.str_('182/WTrigger2/Filler/182/-/-/Buruko minagatik joan da urgentzietara agure zaharra/Abs'): 233,
#  np.str_('183/WTrigger2/Critical/183/Unamb/4/Ezezagun hark ordu txikitan trafikatu du zubipean/Erg'): 234,
#  np.str_('183/WTrigger2/Filler/183/-/-/Burgosetik etorri den nire laguna da hau/Abs'): 235,
#  np.str_('184/WTrigger2/Critical/184/Unamb/3/Laguntzaile hau goizean goiz iratzartu da muntaketarako/Abs'): 236,
#  np.str_('184/WTrigger2/Filler/184/-/-/Errekaren alboan igaro dute arratsaldea lagunek Oñatin/Erg'): 237,
#  np.str_('185/WTrigger2/Critical/185/Amb/2/Famatu horiek telebistako saioan distiratu dute oraingoan/Erg'): 238,
#  np.str_('185/WTrigger2/Filler/185/-/-/Markizeko kobak bisitatu zituzten arratsaldean nan nan/Erg'): 239,
#  np.str_('186/WTrigger2/Critical/186/Amb/1/Gizon haiek gauerdi inguruan berragertu dira tabernan/Abs'): 240,
#  np.str_('186/WTrigger2/Filler/186/-/-/Martari kontauko diot pasatu dena nan nan/Erg'): 241,
#  np.str_('187/WTrigger2/Critical/187/Unamb/4/Iheslari honek ikerketa berrian kolaboratu du ustekabean/Erg'): 242,
#  np.str_('187/WTrigger2/Filler/187/-/-/Liburuaren atzekaldean egin du sinadura idazle ospetsuak/Erg'): 243,
#  np.str_('188/WTrigger2/Critical/188/Unamb/3/Basozain hori baserriko lursailetan berragertu da goizean/Abs'): 244,
#  np.str_('188/WTrigger2/Filler/188/-/-/Elizaren aurrean egin dute dantza balleteko ikasleek/Erg'): 245,
#  np.str_('189/WTrigger2/Critical/189/Amb/2/Lapur haiek Ondarruko portuan trafikatu dute iluntzean/Erg'): 246,
#  np.str_('189/WTrigger2/Filler/189/-/-/Ikertzailearen eskaerak ezekoa jaso zuen epaimahaian nan/Erg'): 247,
#  np.str_('19/WTrigger2/Critical/19/Unamb/4/Gaixo honek ikarak jota sufritu du anbulantzian/Erg'): 248,
#  np.str_('19/WTrigger2/Filler/19/Unamb/-/Postari horrek kaxa bat banatu du nan/Erg'): 249,
#  np.str_('190/WTrigger2/Critical/190/Amb/1/Biolinista hauek nazioarteko jaialdian desorientatu dira gauean/Abs'): 250,
#  np.str_('190/WTrigger2/Filler/190/-/-/Hilketaren egunean jaso zuen mezua amonak nan/Erg'): 251,
#  np.str_('191/WTrigger2/Critical/191/Unamb/4/Mendizale horrek gaua iristean deskantsatu du Aizkorrin/Erg'): 252,
#  np.str_('191/WTrigger2/Filler/191/-/-/Malagatik heldu da nire lehengusua gaur nan/Abs'): 253,
#  np.str_('192/WTrigger2/Critical/192/Unamb/3/Erreportari hura denbora luzez desorientatu da telebistan/Abs'): 254,
#  np.str_('192/WTrigger2/Filler/192/-/-/Errekuperatzeko saioetan nabil istripua izan nuenetik nan/Abs'): 255,
#  np.str_('2/WTrigger1/Critical/1/Amb/2/Aizkolari hauek gaur goizean jokatu dute Bilbon/Erg'): 256,
#  np.str_('2/WTrigger1/Critical/101/Amb/2/Sorgin horiek hiru orduz pentsatu dute etxolan/Erg'): 257,
#  np.str_('2/WTrigger1/Critical/105/Amb/2/Aita haiek seme-alaben kustodiagatik argudiatu dute gaur/Erg'): 258,
#  np.str_('2/WTrigger1/Critical/109/Amb/2/Testigu hauek oso bizkor deklaratu dute epaitegian/Erg'): 259,
#  np.str_('2/WTrigger1/Critical/113/Amb/2/Jakintsu horiek denbora luzez predikatu dute bidaian/Erg'): 260,
#  np.str_('2/WTrigger1/Critical/117/Amb/2/Hippy haiek diru gutxirekin bidaiatu dute Ameriketatik/Erg'): 261,
#  np.str_('2/WTrigger1/Critical/121/Amb/2/Haur hauek oporraldi garaian antzeztu dute uztailean/Erg'): 262,
#  np.str_('2/WTrigger1/Critical/129/Amb/2/Jokalari haiek hasi orduko izerditu dute zelaian/Erg'): 263,
#  np.str_('2/WTrigger1/Critical/13/Amb/2/Ikasle hauek eguerdi inguruan bozkatu dute ikasgelan/Erg'): 264,
#  np.str_('2/WTrigger1/Critical/133/Amb/2/Soprano hauek hilero hilero kotizatu dute aurten/Erg'): 265,
#  np.str_('2/WTrigger1/Critical/137/Amb/2/Dantzari horiek Arriagako eszenatokian entsaiatu dute goizean/Erg'): 266,
#  np.str_('2/WTrigger1/Critical/141/Amb/2/Mutiko haiek amonaren alboan kozinatu dute umetatik/Erg'): 267,
#  np.str_('2/WTrigger1/Critical/145/Amb/2/Militar hauek Kubako gerrillan borrokatu dute aurten/Erg'): 268,
#  np.str_('2/WTrigger1/Critical/149/Amb/2/Tertuliakide horiek gogo biziz eztabaidatu dute laguntzez/Erg'): 269,
#  np.str_('2/WTrigger1/Critical/153/Amb/2/Boluntario haiek euren artean xuxurlatu dute bileran/Erg'): 270,
#  np.str_('2/WTrigger1/Critical/157/Amb/2/Arraunlari hauek itsaso zabalean entrenatu dute goizaldean/Erg'): 271,
#  np.str_('2/WTrigger1/Critical/161/Amb/2/Foruzain horiek kuriositate handiz hausnartu dute istripuaz/Erg'): 272,
#  np.str_('2/WTrigger1/Critical/165/Amb/2/Masajista haiek entrenatzailearen esanetara funtzionatu dute zelaian/Erg'): 273,
#  np.str_('2/WTrigger1/Critical/169/Amb/2/Intsumiso hauek igandeko hauteskundeetan protestatu dute berriro/Erg'): 274,
#  np.str_('2/WTrigger1/Critical/17/Amb/2/Manifestari horiek gogoz kontra etsi dute bileran/Erg'): 275,
#  np.str_('2/WTrigger1/Critical/173/Amb/2/Erretiratu horiek goizeko ibilaldian disfrutatu dute lakuaz/Erg'): 276,
#  np.str_('2/WTrigger1/Critical/177/Amb/2/Ikertzaile haiek itsasoko espedizioan kolaboratu dute proiektuan/Erg'): 277,
#  np.str_('2/WTrigger1/Critical/181/Amb/2/Zauritu hauek ospitaleko logelan deskantsatu dute gaur/Erg'): 278,
#  np.str_('2/WTrigger1/Critical/185/Amb/2/Famatu horiek telebistako saioan distiratu dute oraingoan/Erg'): 279,
#  np.str_('2/WTrigger1/Critical/189/Amb/2/Lapur haiek Ondarruko portuan trafikatu dute iluntzean/Erg'): 280,
#  np.str_('2/WTrigger1/Critical/21/Amb/2/Baserritar haiek mendiko zelaiez gozatu dute arratsaldean/Erg'): 281,
#  np.str_('2/WTrigger1/Critical/25/Amb/2/Zirujau hauek benetan izugarri sufritu dute albistearekin/Erg'): 282,
#  np.str_('2/WTrigger1/Critical/29/Amb/2/Haurtxo horiek oso pozik abestu dute iluntzean/Erg'): 283,
#  np.str_('2/WTrigger1/Critical/33/Amb/2/Pintore haiek pandemia garaian margotu dute gehien/Erg'): 284,
#  np.str_('2/WTrigger1/Critical/37/Amb/2/Neskatila hauek arratsalde amaieran jolastu dute parkean/Erg'): 285,
#  np.str_('2/WTrigger1/Critical/41/Amb/2/Bisitari horiek atsedenaren ostean paseatu dute freskatzeko/Erg'): 286,
#  np.str_('2/WTrigger1/Critical/45/Amb/2/Ingeniari haiek laneko bidaian eskiatu dute gehienbat/Erg'): 287,
#  np.str_('2/WTrigger1/Critical/49/Amb/2/Ikerlari hauek espero gabe jarraitu dute lanean/Erg'): 288,
#  np.str_('2/WTrigger1/Critical/5/Amb/2/Preso horiek laguntzei esker iraun dute kartzelan/Erg'): 289,
#  np.str_('2/WTrigger1/Critical/53/Amb/2/Alaba horiek amonaren altzoan kantatu dute goizean/Erg'): 290,
#  np.str_('2/WTrigger1/Critical/57/Amb/2/Feminista haiek erasotzailearen aurka oihukatu dute tabernan/Erg'): 291,
#  np.str_('2/WTrigger1/Critical/61/Amb/2/Pianista hauek gaurko saioan debutatu dute zuzendariarekin/Erg'): 292,
#  np.str_('2/WTrigger1/Critical/65/Amb/2/Parroko horiek aita-santuaren hitzekin errezatu dute Vatikanoan/Erg'): 293,
#  np.str_('2/WTrigger1/Critical/69/Amb/2/Neska haiek determinazio osoz abortatu dute goizean/Erg'): 294,
#  np.str_('2/WTrigger1/Critical/73/Amb/2/Migratzaile hauek eguraldi txarrarekin nabigatu dute goizean/Erg'): 295,
#  np.str_('2/WTrigger1/Critical/77/Amb/2/Herritar horiek auzotarren jarreragatik emigratu dute goizean/Erg'): 296,
#  np.str_('2/WTrigger1/Critical/81/Amb/2/Nekazari haiek eguraldiaren ondorioz tardatu dute bidean/Erg'): 297,
#  np.str_('2/WTrigger1/Critical/85/Amb/2/Senide hauek hondartza ertzean flotatu dute koltxonetan/Erg'): 298,
#  np.str_('2/WTrigger1/Critical/89/Amb/2/Gaizkile horiek poliziaren aurrean patinatu dute ustekabean/Erg'): 299,
#  np.str_('2/WTrigger1/Critical/9/Amb/2/Malabarista haiek euriaren eraginez itxaron dute aterpean/Erg'): 300,
#  np.str_('2/WTrigger1/Critical/93/Amb/2/Arkitekto haiek aste honetan meditatu dute etorkizunaz/Erg'): 301,
#  np.str_('2/WTrigger1/Critical/97/Amb/2/Ertzain hauek kontu handiarekin begiratu dute eraikinerantz/Erg'): 302,
#  np.str_('2/WTrigger2/Critical/2/Amb/1/Mutil horiek guztiz ezkutuan iragan dira baserritik/Abs'): 303,
#  np.str_('2/WTrigger2/Filler/2/Unamb/-/Guraso hark goxoki garestiena erosi du nan/Erg'): 304,
#  np.str_('20/WTrigger2/Critical/20/Unamb/3/Kantari hori piano ondoan eseri da kontzertuan/Abs'): 305,
#  np.str_('20/WTrigger2/Filler/20/Unamb/-/Bikote hark opari piloa ekarri du nan/Erg'): 306,
#  np.str_('200/WTriggerFix/Critical/1/Amb/2/Aizkolari hauek gaur goizean jokatu dute Bilbon/Erg'): 307,
#  np.str_('200/WTriggerFix/Critical/10/Amb/1/Diseinatzaile hauek esperantza handiz jaitsi dira sariketara/Abs'): 308,
#  np.str_('200/WTriggerFix/Critical/100/Unamb/3/Abokatu hau hamaikak aldera hurbildu da epaitegira/Abs'): 309,
#  np.str_('200/WTriggerFix/Critical/101/Amb/2/Sorgin horiek hiru orduz pentsatu dute etxolan/Erg'): 310,
#  np.str_('200/WTriggerFix/Critical/102/Amb/1/Bezero haiek denbora luzez ezkutatu dira saltokian/Abs'): 311,
#  np.str_('200/WTriggerFix/Critical/103/Unamb/4/Bitartekari honek mehatxuen ondorioz deklaratu du etxetik/Erg'): 312,
#  np.str_('200/WTriggerFix/Critical/104/Unamb/3/Atleta hori oraintxe bertan ezkutatu da harmailetan/Abs'): 313,
#  np.str_('200/WTriggerFix/Critical/105/Amb/2/Aita haiek seme-alaben kustodiagatik argudiatu dute gaur/Erg'): 314,
#  np.str_('200/WTriggerFix/Critical/106/Amb/1/Kontseilari hauek pandemia egoeragatik arduratu dira prentsaurrean/Abs'): 315,
#  np.str_('200/WTriggerFix/Critical/107/Unamb/4/Gitarrista horrek managerrekin batera begiratu du publikorantz/Erg'): 316,
#  np.str_('200/WTriggerFix/Critical/108/Unamb/3/Tutore hura denbora luzez arduratu da arazoaz/Abs'): 317,
#  np.str_('200/WTriggerFix/Critical/109/Amb/2/Testigu hauek oso bizkor deklaratu dute epaitegian/Erg'): 318,
#  np.str_('200/WTriggerFix/Critical/11/Unamb/4/Kirolari horrek luzaketen ostean jokatu du kantxan/Erg'): 319,
#  np.str_('200/WTriggerFix/Critical/110/Amb/1/Ekologista horiek urduritasun itxuraz ailegatu dira kongresura/Abs'): 320,
#  np.str_('200/WTriggerFix/Critical/111/Unamb/4/Ekintzaile hark kezka handiz pentsatu du bileran/Erg'): 321,
#  np.str_('200/WTriggerFix/Critical/112/Unamb/3/Alkate hau harrokeria handiz ailegatu da udaletxera/Abs'): 322,
#  np.str_('200/WTriggerFix/Critical/113/Amb/2/Jakintsu horiek denbora luzez predikatu dute bidaian/Erg'): 323,
#  np.str_('200/WTriggerFix/Critical/114/Amb/1/Funtzionario haiek espero bezala atzeratu dira oporretan/Abs'): 324,
#  np.str_('200/WTriggerFix/Critical/115/Unamb/4/Ikasle honek ordu erdiz antzeztu du jolastorduan/Erg'): 325,
#  np.str_('200/WTriggerFix/Critical/116/Unamb/3/Ordezkari hori istiluen ondorioz atzeratu da batzordean/Abs'): 326,
#  np.str_('200/WTriggerFix/Critical/117/Amb/2/Hippy haiek diru gutxirekin bidaiatu dute Ameriketatik/Erg'): 327,
#  np.str_('200/WTriggerFix/Critical/118/Amb/1/Aktore hauek guztiz burumakur bueltatu dira grabaziotik/Abs'): 328,
#  np.str_('200/WTriggerFix/Critical/119/Unamb/4/Diruzain horrek oso damututa dimititu du kargutik/Erg'): 329,
#  np.str_('200/WTriggerFix/Critical/12/Unamb/3/Diputatu hura urte luzez jaitsi da herritarrengana/Abs'): 330,
#  np.str_('200/WTriggerFix/Critical/120/Unamb/3/Apezpiku hura neke aurpegiaz bueltatu da Erromatik/Abs'): 331,
#  np.str_('200/WTriggerFix/Critical/121/Amb/2/Haur hauek oporraldi garaian antzeztu dute uztailean/Erg'): 332,
#  np.str_('200/WTriggerFix/Critical/122/Amb/1/Zinegotzi horiek jaien astean murgildu dira Gasteizen/Abs'): 333,
#  np.str_('200/WTriggerFix/Critical/123/Unamb/4/Misiolari hark indigenen artean predikatu du Hondurasen/Erg'): 334,
#  np.str_('200/WTriggerFix/Critical/124/Unamb/3/Turista hau Mexikon barrena murgildu da abuztuan/Abs'): 335,
#  np.str_('200/WTriggerFix/Critical/125/Amb/2/Politikari horiek guztiz ezkutuan dimititu dute amarruarengatik/Erg'): 336,
#  np.str_('200/WTriggerFix/Critical/126/Amb/1/Lider haiek urteetan zehar aberastu dira bilkurekin/Abs'): 337,
#  np.str_('200/WTriggerFix/Critical/127/Unamb/4/Farmazialari honek txertoei esker bidaiatu du Alemaniara/Erg'): 338,
#  np.str_('200/WTriggerFix/Critical/128/Unamb/3/Umorista hori managerrari esker aberastu da pelikulekin/Abs'): 339,
#  np.str_('200/WTriggerFix/Critical/129/Amb/2/Jokalari haiek hasi orduko izerditu dute zelaian/Erg'): 340,
#  np.str_('200/WTriggerFix/Critical/13/Amb/2/Ikasle hauek eguerdi inguruan bozkatu dute ikasgelan/Erg'): 341,
#  np.str_('200/WTriggerFix/Critical/130/Amb/1/Youtuber hauek urtero bezala aztoratu dira partiduarekin/Abs'): 342,
#  np.str_('200/WTriggerFix/Critical/131/Unamb/4/Tronpetista horrek zuzendaria sartzean entsaiatu du arratsaldean/Erg'): 343,
#  np.str_('200/WTriggerFix/Critical/132/Unamb/3/Sukaldari hura ardoa edanda aztoratu da elkartean/Abs'): 344,
#  np.str_('200/WTriggerFix/Critical/133/Amb/2/Soprano hauek hilero hilero kotizatu dute aurten/Erg'): 345,
#  np.str_('200/WTriggerFix/Critical/134/Amb/1/Musikari horiek bazkal ostean mozkortu dira frontoian/Abs'): 346,
#  np.str_('200/WTriggerFix/Critical/135/Unamb/4/Tabernari hark herriko festetan kozinatu du gazteentzako/Erg'): 347,
#  np.str_('200/WTriggerFix/Critical/136/Unamb/3/Nerabe hau BBK jaialdian mozkortu da horrenbeste/Abs'): 348,
#  np.str_('200/WTriggerFix/Critical/137/Amb/2/Dantzari horiek Arriagako eszenatokian entsaiatu dute goizean/Erg'): 349,
#  np.str_('200/WTriggerFix/Critical/138/Amb/1/Futbolzale haiek hamabiak aldera lesionatu dira plazan/Abs'): 350,
#  np.str_('200/WTriggerFix/Critical/139/Unamb/4/Korrikalari honek eguzki galdatan izerditu du mendian/Erg'): 351,
#  np.str_('200/WTriggerFix/Critical/14/Amb/1/Boxeolari horiek azken unean erori dira lurrera/Abs'): 352,
#  np.str_('200/WTriggerFix/Critical/140/Unamb/3/Harakin hori bere jardunagatik lesionatu da oraingoan/Abs'): 353,
#  np.str_('200/WTriggerFix/Critical/141/Amb/2/Mutiko haiek amonaren alboan kozinatu dute umetatik/Erg'): 354,
#  np.str_('200/WTriggerFix/Critical/142/Amb/1/Neskatila hauek ziztu bizian koskortu dira futbolean/Abs'): 355,
#  np.str_('200/WTriggerFix/Critical/143/Unamb/4/Gaztetxo horrek konturatu gabe kotizatu du lanean/Erg'): 356,
#  np.str_('200/WTriggerFix/Critical/144/Unamb/3/Ume hura musikariz inguratuta koskortu da herrian/Abs'): 357,
#  np.str_('200/WTriggerFix/Critical/145/Amb/2/Militar hauek Kubako gerrillan borrokatu dute aurten/Erg'): 358,
#  np.str_('200/WTriggerFix/Critical/146/Amb/1/Aurkezle horiek telebistako estudioetan desagertu dira iluntzean/Abs'): 359,
#  np.str_('200/WTriggerFix/Critical/147/Unamb/4/Lagun hark besteen ezkutuan xuxurlatu du bazkarian/Erg'): 360,
#  np.str_('200/WTriggerFix/Critical/148/Unamb/3/Txirrindulari hau hiru egunez desagertu da Pirinioetan/Abs'): 361,
#  np.str_('200/WTriggerFix/Critical/149/Amb/2/Tertuliakide horiek gogo biziz eztabaidatu dute laguntzez/Erg'): 362,
#  np.str_('200/WTriggerFix/Critical/15/Unamb/4/Pirata hark ardoz lepo iraun du itsasoan/Erg'): 363,
#  np.str_('200/WTriggerFix/Critical/150/Amb/1/Adiskide haiek modu ezkutuan ahalegindu dira kopiatzen/Abs'): 364,
#  np.str_('200/WTriggerFix/Critical/151/Unamb/4/Pertikalari honek kemen handiz entrenatu du hobetzeko/Erg'): 365,
#  np.str_('200/WTriggerFix/Critical/152/Unamb/3/Palestinar hori urteetan zehar ahalegindu da liberatzen/Abs'): 366,
#  np.str_('200/WTriggerFix/Critical/153/Amb/2/Boluntario haiek euren artean xuxurlatu dute bileran/Erg'): 367,
#  np.str_('200/WTriggerFix/Critical/154/Amb/1/Atezain hauek berebiziko energiaz haserretu dira partiduan/Abs'): 368,
#  np.str_('200/WTriggerFix/Critical/155/Unamb/4/Detektibe horrek tarte luzez borrokatu du poliziarekin/Erg'): 369,
#  np.str_('200/WTriggerFix/Critical/156/Unamb/3/Kazetari hura telefono deian haserretu da editoreekin/Abs'): 370,
#  np.str_('200/WTriggerFix/Critical/157/Amb/2/Arraunlari hauek itsaso zabalean entrenatu dute goizaldean/Erg'): 371,
#  np.str_('200/WTriggerFix/Critical/158/Amb/1/Gerlari horiek urruneko itsasotan hondoratu dira zoritxarrez/Abs'): 372,
#  np.str_('200/WTriggerFix/Critical/159/Unamb/4/Alargun hark galeraren saminaz eztabaidatu du tanatorioan/Erg'): 373,
#  np.str_('200/WTriggerFix/Critical/16/Unamb/3/Gazte hau kanpuseko aretoan erori da goizean/Abs'): 374,
#  np.str_('200/WTriggerFix/Critical/160/Unamb/3/Bidaiari hau oso leunki hondoratu da itsasoan/Abs'): 375,
#  np.str_('200/WTriggerFix/Critical/161/Amb/2/Foruzain horiek kuriositate handiz hausnartu dute istripuaz/Erg'): 376,
#  np.str_('200/WTriggerFix/Critical/162/Amb/1/Langile haiek prestutasun handiz gerturartu dira taldera/Abs'): 377,
#  np.str_('200/WTriggerFix/Critical/163/Unamb/4/Bizilagun honek kaleko zaratengatik protestatu du balkoian/Erg'): 378,
#  np.str_('200/WTriggerFix/Critical/164/Unamb/3/Pilotu hori hegazkin bidaian gerturartu da Donostiara/Abs'): 379,
#  np.str_('200/WTriggerFix/Critical/165/Amb/2/Masajista haiek entrenatzailearen esanetara funtzionatu dute zelaian/Erg'): 380,
#  np.str_('200/WTriggerFix/Critical/166/Amb/1/Langabe hauek udaletxearen ondoan belaunikatu dira manifestazioan/Abs'): 381,
#  np.str_('200/WTriggerFix/Critical/167/Unamb/4/Fededun horrek apaizaren hitzekin disfrutatu du mezetan/Erg'): 382,
#  np.str_('200/WTriggerFix/Critical/168/Unamb/3/Mandatari hura elizaren atarian belaunikatu da goizean/Abs'): 383,
#  np.str_('200/WTriggerFix/Critical/169/Amb/2/Intsumiso hauek igandeko hauteskundeetan protestatu dute berriro/Erg'): 384,
#  np.str_('200/WTriggerFix/Critical/17/Amb/2/Manifestari horiek gogoz kontra etsi dute bileran/Erg'): 385,
#  np.str_('200/WTriggerFix/Critical/170/Amb/1/Bazkide horiek osteguneko batzordean abstenitu dira giroagatik/Abs'): 386,
#  np.str_('200/WTriggerFix/Critical/171/Unamb/4/Filosofo hark konbentzimendu osoz hausnartu du hausteskundeetaz/Erg'): 387,
#  np.str_('200/WTriggerFix/Critical/172/Unamb/3/Lankide hau taldearekin bat abstenitu da batzordean/Abs'): 388,
#  np.str_('200/WTriggerFix/Critical/173/Amb/2/Erretiratu horiek goizeko ibilaldian disfrutatu dute lakuaz/Erg'): 389,
#  np.str_('200/WTriggerFix/Critical/174/Amb/1/Poeta haiek unibertsitateko aretoan irristatu dira gauean/Abs'): 390,
#  np.str_('200/WTriggerFix/Critical/175/Unamb/4/Patinatzaile honek lehiaketan gaizki funtzionatu du tamalez/Erg'): 391,
#  np.str_('200/WTriggerFix/Critical/176/Unamb/3/Modelo hori takoidun oinetakoekin irristatu da agerraldian/Abs'): 392,
#  np.str_('200/WTriggerFix/Critical/177/Amb/2/Ikertzaile haiek itsasoko espedizioan kolaboratu dute proiektuan/Erg'): 393,
#  np.str_('200/WTriggerFix/Critical/178/Amb/1/Emakume hauek beroaren eraginez zorabiatu dira ibilaldian/Abs'): 394,
#  np.str_('200/WTriggerFix/Critical/179/Unamb/4/Neska horrek eguzki izpiekin distiratu du eguerdian/Erg'): 395,
#  np.str_('200/WTriggerFix/Critical/18/Amb/1/Frantziar haiek ilusio handiz eseri dira jatetxean/Abs'): 396,
#  np.str_('200/WTriggerFix/Critical/180/Unamb/3/Mutil hura azkenaldian gehiegi zorabiatu da tamalez/Abs'): 397,
#  np.str_('200/WTriggerFix/Critical/181/Amb/2/Zauritu hauek ospitaleko logelan deskantsatu dute gaur/Erg'): 398,
#  np.str_('200/WTriggerFix/Critical/182/Amb/1/Haur horiek gurasoen laguntzaz iratzartu dira lehiaketarako/Abs'): 399,
#  np.str_('200/WTriggerFix/Critical/183/Unamb/4/Ezezagun hark ordu txikitan trafikatu du zubipean/Erg'): 400,
#  np.str_('200/WTriggerFix/Critical/184/Unamb/3/Laguntzaile hau goizean goiz iratzartu da muntaketarako/Abs'): 401,
#  np.str_('200/WTriggerFix/Critical/185/Amb/2/Famatu horiek telebistako saioan distiratu dute oraingoan/Erg'): 402,
#  np.str_('200/WTriggerFix/Critical/186/Amb/1/Gizon haiek gauerdi inguruan berragertu dira tabernan/Abs'): 403,
#  np.str_('200/WTriggerFix/Critical/187/Unamb/4/Iheslari honek ikerketa berrian kolaboratu du ustekabean/Erg'): 404,
#  np.str_('200/WTriggerFix/Critical/188/Unamb/3/Basozain hori baserriko lursailetan berragertu da goizean/Abs'): 405,
# ...
#  np.str_('203/WTrigger3/Critical/66/Amb/1/Emakume haiek klinikako medikuekin harrotu dira gaur/Abs'): 846,
#  np.str_('203/WTrigger3/Critical/67/Unamb/4/Esploratzaile honek kapitainaren mezuekin nabigatu du goizean/Erg'): 847,
#  np.str_('203/WTrigger3/Critical/68/Unamb/3/Atzerritar hori beste behin harrotu da jaietan/Abs'): 848,
#  np.str_('203/WTrigger3/Critical/69/Amb/2/Neska haiek determinazio osoz abortatu dute goizean/Erg'): 849,
#  np.str_('203/WTrigger3/Critical/7/Unamb/4/Hautagai honek lehen orduan bozkatu du kalean/Erg'): 850,
#  np.str_('203/WTrigger3/Critical/70/Amb/1/Lehiakide hauek asko kostata altxatu dira Amazonasen/Abs'): 851,
#  np.str_('203/WTrigger3/Critical/71/Unamb/4/Mexikar horrek injustizien ondorioz emigratu du herrialdetik/Erg'): 852,
#  np.str_('203/WTrigger3/Critical/72/Unamb/3/Sinisdun hura gerren aurka altxatu da herrian/Abs'): 853,
#  np.str_('203/WTrigger3/Critical/73/Amb/2/Migratzaile hauek eguraldi txarrarekin nabigatu dute goizean/Erg'): 854,
#  np.str_('203/WTrigger3/Critical/74/Amb/1/Eskale horiek egoeraren ondorioz larritu dira zoritxarrez/Abs'): 855,
#  np.str_('203/WTrigger3/Critical/75/Unamb/4/Abade hark albistea entzutean errezatu du segituan/Erg'): 856,
#  np.str_('203/WTrigger3/Critical/76/Unamb/3/Emazte hau ebakuntzaren eraginez larritu da ospitalean/Abs'): 857,
#  np.str_('203/WTrigger3/Critical/77/Amb/2/Herritar horiek auzotarren jarreragatik emigratu dute goizean/Erg'): 858,
#  np.str_('203/WTrigger3/Critical/78/Amb/1/Senegaldar haiek abadearen hitzekin lotsatu dira mezan/Abs'): 859,
#  np.str_('203/WTrigger3/Critical/79/Unamb/4/Erregina honek guztiz isilpean abortatu du istiluengatik/Erg'): 860,
#  np.str_('203/WTrigger3/Critical/8/Unamb/3/Futbolari hori gogo biziz irten da zelaira/Abs'): 861,
#  np.str_('203/WTrigger3/Critical/80/Unamb/3/Arrantzale hori nagusiaren aginduekin lotsatu da itsasoan/Abs'): 862,
#  np.str_('203/WTrigger3/Critical/81/Amb/2/Nekazari haiek eguraldiaren ondorioz tardatu dute bidean/Erg'): 863,
#  np.str_('203/WTrigger3/Critical/82/Amb/1/Igerilari hauek lehiaketaren ostean gaixotu dira hondartzan/Abs'): 864,
#  np.str_('203/WTrigger3/Critical/83/Unamb/4/Alemaniar horrek laku ondoan patinatu du eguerdian/Erg'): 865,
#  np.str_('203/WTrigger3/Critical/84/Unamb/3/Historialari hura mendiko egonaldian gaixotu da asteburuan/Abs'): 866,
#  np.str_('203/WTrigger3/Critical/85/Amb/2/Senide hauek hondartza ertzean flotatu dute koltxonetan/Erg'): 867,
#  np.str_('203/WTrigger3/Critical/86/Amb/1/Gimnasta horiek poliki poliki lokartu dira ilunabarrean/Abs'): 868,
#  np.str_('203/WTrigger3/Critical/87/Unamb/4/Maistra hark yoga klasean meditatu du arratsaldean/Erg'): 869,
#  np.str_('203/WTrigger3/Critical/88/Unamb/3/Hautesle hau osasun arazoengatik lokartu da azkenean/Abs'): 870,
#  np.str_('203/WTrigger3/Critical/89/Amb/2/Gaizkile horiek poliziaren aurrean patinatu dute ustekabean/Erg'): 871,
#  np.str_('203/WTrigger3/Critical/9/Amb/2/Malabarista haiek euriaren eraginez itxaron dute aterpean/Erg'): 872,
#  np.str_('203/WTrigger3/Critical/90/Amb/1/Ministro haiek manifestazioa ikustean kikildu dira hotelean/Abs'): 873,
#  np.str_('203/WTrigger3/Critical/91/Unamb/4/Gidari honek ertzainaren errietagatik tardatu du errepidean/Erg'): 874,
#  np.str_('203/WTrigger3/Critical/92/Unamb/3/Surflari hori olatu handiekin kikildu da hondartzan/Abs'): 875,
#  np.str_('203/WTrigger3/Critical/93/Amb/2/Arkitekto haiek aste honetan meditatu dute etorkizunaz/Erg'): 876,
#  np.str_('203/WTrigger3/Critical/94/Amb/1/Famatu hauek istripuaren eraginez banandu dira azkenean/Abs'): 877,
#  np.str_('203/WTrigger3/Critical/95/Unamb/4/Aberats horrek udako oporretan flotatu du hondartzan/Erg'): 878,
#  np.str_('203/WTrigger3/Critical/96/Unamb/3/Idazle hura astelehen goizean banandu da Gasteizen/Abs'): 879,
#  np.str_('203/WTrigger3/Critical/97/Amb/2/Ertzain hauek kontu handiarekin begiratu dute eraikinerantz/Erg'): 880,
#  np.str_('203/WTrigger3/Critical/98/Amb/1/Astronauta horiek ordu luzez hurbildu dira Ilargirantz/Abs'): 881,
#  np.str_('203/WTrigger3/Critical/99/Unamb/4/Gobernari hark jarrera oldarkorraz argudiatu du parlamentuan/Erg'): 882,
#  np.str_('203/WTrigger3/Filler/1/Unamb/-/Abeltzain horrek diru mordoa zor du nan/Erg'): 883,
#  np.str_('203/WTrigger3/Filler/10/Unamb/-/Taberna horrek zarata ozena egin du nan/Erg'): 884,
#  np.str_('203/WTrigger3/Filler/100/-/-/Aspaldi batean amonak asko josten zuen nan/Erg'): 885,
#  np.str_('203/WTrigger3/Filler/101/-/-/Inola ere ez dute oparituko baloia nan/Erg'): 886,
#  np.str_('203/WTrigger3/Filler/102/-/-/Uztail erdialdean lagunak etxea berriztu zuen nan/Erg'): 887,
#  np.str_('203/WTrigger3/Filler/103/-/-/Iazko abenduan iritsi zen ikasle berria herrira/Abs'): 888,
#  np.str_('203/WTrigger3/Filler/104/-/-/Sekulako zalapartarekin sartu da etxera mozkor hori/Abs'): 889,
#  np.str_('203/WTrigger3/Filler/105/-/-/Sutondoan eseri da zure osaba Nicolas nan/Abs'): 890,
#  np.str_('203/WTrigger3/Filler/106/-/-/Frontoian izan da aurtengo herri bazkaria Lizarran/Abs'): 891,
#  np.str_('203/WTrigger3/Filler/107/-/-/Hirugarren aldiz ezkondu da gizon hori aurten/Abs'): 892,
#  np.str_('203/WTrigger3/Filler/108/-/-/Modu baldarrean erori nintzen lurrera atzo nan/Abs'): 893,
#  np.str_('203/WTrigger3/Filler/109/Unamb/-/Emakumeek lan ikarragarria egin dute nan nan/Erg'): 894,
#  np.str_('203/WTrigger3/Filler/11/Unamb/-/Zaintzaile hark etxe osoa garbitu du nan/Erg'): 895,
#  np.str_('203/WTrigger3/Filler/110/Unamb/-/Txiroek laguntza gehiago behar dituzte errentak ordaintzeko/Erg'): 896,
#  np.str_('203/WTrigger3/Filler/111/Unamb/-/Festek herri osoa alaitu dute aurtengo udan/Erg'): 897,
#  np.str_('203/WTrigger3/Filler/112/Unamb/-/Hartzek ez ohi dute zomorrorik jaten nan/Erg'): 898,
#  np.str_('203/WTrigger3/Filler/113/Unamb/-/Otsoek taldean ehizatzen dituzte ardiak gehienetan nan/Erg'): 899,
#  np.str_('203/WTrigger3/Filler/114/Unamb/-/Lapurrek ez zuten arrastorik utzi etxean nan/Erg'): 900,
#  np.str_('203/WTrigger3/Filler/115/Unamb/-/Birkiek jende asko ezagutu dute beti nan/Erg'): 901,
#  np.str_('203/WTrigger3/Filler/116/Amb/-/Atsoak bosgarren aldian lortu zuen laguna konbentzitzea/Erg'): 902,
#  np.str_('203/WTrigger3/Filler/117/Amb/-/Txakurrak zaunka pasa zuen arratsalde osoa atzo/Erg'): 903,
#  np.str_('203/WTrigger3/Filler/118/Amb/-/Postariak motxila bete betea zeraman bizikletan zihoala/Erg'): 904,
#  np.str_('203/WTrigger3/Filler/119/Amb/-/Fakirrak ikuskizun polita eskaini zuen zirkuan nan/Erg'): 905,
#  np.str_('203/WTrigger3/Filler/12/Unamb/-/Fakir honek orratz luzea irentsi du nan/Erg'): 906,
#  np.str_('203/WTrigger3/Filler/120/Amb/-/Produktoreak ez zuen begi onez ikusi pelikularen/Erg'): 907,
#  np.str_('203/WTrigger3/Filler/121/Amb/-/Armiarmak umea izutu du baserrian nan nan/Erg'): 908,
#  np.str_('203/WTrigger3/Filler/122/Amb/-/Azeriak baserritarraren bi oilo jan ditu nan/Erg'): 909,
#  np.str_('203/WTrigger3/Filler/123/Amb/-/Jaioberriak oso azkar nekatzen dira egunean zehar/Abs'): 910,
#  np.str_('203/WTrigger3/Filler/124/Amb/-/Matematikariak ez dira iritsi ekuazio hori ebaztera/Abs'): 911,
#  np.str_('203/WTrigger3/Filler/125/Amb/-/Ospakizunak bertan behera geratu dira tamalez nan/Abs'): 912,
#  np.str_('203/WTrigger3/Filler/126/Amb/-/Zirujauak etorri zaizkigu operazioaren berri ematera nan/Abs'): 913,
#  np.str_('203/WTrigger3/Filler/127/Amb/-/Artzainak mendian zehar ibili dira txakurraren bila/Abs'): 914,
#  np.str_('203/WTrigger3/Filler/128/Amb/-/Influencerrak oso aberats egin dira azken urtean/Abs'): 915,
#  np.str_('203/WTrigger3/Filler/129/Amb/-/Paperak beharko ditugu arratsaldeko eskulana ondo egiteko/Abs'): 916,
#  np.str_('203/WTrigger3/Filler/13/Unamb/-/Lotsagabe horrek irain larria bota du nan/Erg'): 917,
#  np.str_('203/WTrigger3/Filler/130/Unamb/-/Kakahuetea trabatu zaio eztarrian gizonari nan nan/Abs'): 918,
#  np.str_('203/WTrigger3/Filler/131/Unamb/-/Dokumentua prest dago jada irakurri nahi baduzu/Abs'): 919,
#  np.str_('203/WTrigger3/Filler/132/Unamb/-/Eulia paretaren kontra zanpatu da nan nan/Abs'): 920,
#  np.str_('203/WTrigger3/Filler/133/Unamb/-/Nerea pozik eta alai joan da etxera/Abs'): 921,
#  np.str_('203/WTrigger3/Filler/134/Unamb/-/Igerilaria zeharo nekatuta iritsi da helmugara lasterketan/Abs'): 922,
#  np.str_('203/WTrigger3/Filler/135/Unamb/-/Maria ez dago etxean momentu honetan nan/Abs'): 923,
#  np.str_('203/WTrigger3/Filler/136/Unamb/-/Josebe oso harro dago bere amonaz nan/Abs'): 924,
#  np.str_('203/WTrigger3/Filler/137/-/-/Urteetan zehar egin dugu kontzertu hau Andramari/Erg'): 925,
#  np.str_('203/WTrigger3/Filler/138/-/-/Larunbat arratsaldean joan ginen amama bisitatzera nan/Abs'): 926,
#  np.str_('203/WTrigger3/Filler/139/-/-/Etzi goizean ikusi zintudan kalean lagunarekin nan/Erg'): 927,
#  np.str_('203/WTrigger3/Filler/14/Unamb/-/Mozkor hark edalontzi bat hautsi du nan/Erg'): 928,
#  np.str_('203/WTrigger3/Filler/140/-/-/Negu osoan egon da Formigaleko eski estazioa/Abs'): 929,
#  np.str_('203/WTrigger3/Filler/141/-/-/Abuztu partean joaten gara normalean Zumaiara oporretan/Abs'): 930,
#  np.str_('203/WTrigger3/Filler/142/-/-/Gauerdi inguruan sartu zen lapurra etxera nan/Abs'): 931,
#  np.str_('203/WTrigger3/Filler/143/-/-/Herenegun eguzkia izan genuen egun osoan zehar/Erg'): 932,
#  np.str_('203/WTrigger3/Filler/144/-/-/Bihar bukatuko ditut azterketak behingoz nan nan/Abs'): 933,
#  np.str_('203/WTrigger3/Filler/145/-/-/Goizean goiz esnatu gara lasterketan parte hartzeko/Abs'): 934,
#  np.str_('203/WTrigger3/Filler/146/-/-/Zergatik etorri zen ere ez daki gizonak/Abs'): 935,
#  np.str_('203/WTrigger3/Filler/147/-/-/Zergatik zegoen negarrez galdetu nion parkeko neskatoari/Abs'): 936,
#  np.str_('203/WTrigger3/Filler/148/-/-/Nolatan agertu zaren jakin nahi nuke nan/Abs'): 937,
#  np.str_('203/WTrigger3/Filler/149/-/-/Zoritxarrez amona erresidentziako eskaileretan erori da arratsaldean/Abs'): 938,
#  np.str_('203/WTrigger3/Filler/15/Unamb/-/Gamelu honek bisitaria gogor kolpatu du nan/Erg'): 939,
#  np.str_('203/WTrigger3/Filler/150/-/-/Ustekabean agertu ziren guardia zibilak bere etxean/Abs'): 940,
#  np.str_('203/WTrigger3/Filler/151/-/-/Bapatean hasi zen elurra egun hartan nan/Abs'): 941,
#  np.str_('203/WTrigger3/Filler/152/-/-/Zorionez ez du inork errepikatu gure klasean/Erg'): 942,
#  np.str_('203/WTrigger3/Filler/153/-/-/Egundoko indarrez jo dio lapurrak diruzainari nan/Erg'): 943,
#  np.str_('203/WTrigger3/Filler/154/-/-/Eguerdiko ordubietan eraman dut haurra eskolara nan/Erg'): 944,
#  np.str_('203/WTrigger3/Filler/155/-/-/Faborea eskertzeko bonboiak oparitu dizkiot irakasleari nan/Erg'): 945,
#  np.str_('203/WTrigger3/Filler/156/-/-/Esfortzu oso txikiarekin iritsi da helmugara hori/Abs'): 946,
#  np.str_('203/WTrigger3/Filler/157/-/-/Kontzertuaren etenean aldatu da jantziz sopranoa nan/Abs'): 947,
#  np.str_('203/WTrigger3/Filler/158/-/-/Etxea apaintzeko ekarri zuen amonak kuadro zaharra/Erg'): 948,
#  np.str_('203/WTrigger3/Filler/159/-/-/Hiltzeraino egin zuen gose greba militante turkiarrak/Erg'): 949,
#  np.str_('203/WTrigger3/Filler/16/Unamb/-/Maizter horrek errenta erdia ordaindu du nan/Erg'): 950,
#  np.str_('203/WTrigger3/Filler/160/-/-/Bere aita alaitzeko ekarri zuen oparia etxera/Erg'): 951,
#  np.str_('203/WTrigger3/Filler/161/-/-/Urtero urtero irakasleek azterketak zuzentzen dituzte garai/Erg'): 952,
#  np.str_('203/WTrigger3/Filler/162/-/-/Kontu handiz ekarri behar dituzu arrautzak oilotegitik/Erg'): 953,
#  np.str_('203/WTrigger3/Filler/163/-/-/Oso bortizki erantzun dio epaileak akusatuari nan/Erg'): 954,
#  np.str_('203/WTrigger3/Filler/164/-/-/Hondartzaren ondoan zerbeza bat hartu dugu arratsaldean/Erg'): 955,
#  np.str_('203/WTrigger3/Filler/165/-/-/Kontseiluaren idazkari nagusia galdu egin zen hirian/Abs'): 956,
#  np.str_('203/WTrigger3/Filler/166/-/-/Euskalgintzako eragileek manifestazio bateratua deitu dute Iruñean/Erg'): 957,
#  np.str_('203/WTrigger3/Filler/167/-/-/Zuzendariaren erruz izan dira irakasle aldaketak nan/Abs'): 958,
#  np.str_('203/WTrigger3/Filler/168/-/-/Errektorearen senarra nire herrikoa da nan nan/Abs'): 959,
#  np.str_('203/WTrigger3/Filler/169/-/-/Ordenagailuko programez hitz egin du adituak irratian/Erg'): 960,
#  np.str_('203/WTrigger3/Filler/17/Unamb/-/Amona hark hiru goxoki oparitu du nan/Erg'): 961,
#  np.str_('203/WTrigger3/Filler/170/-/-/Ikasleen izenean etorri zen bilerara ordezkari hau/Abs'): 962,
#  np.str_('203/WTrigger3/Filler/171/-/-/Ahuntzen esneak onura asko omen ditu osasunarentzat/Erg'): 963,
#  np.str_('203/WTrigger3/Filler/172/-/-/Herriez eta hiriez egin du berba idazleak/Erg'): 964,
#  np.str_('203/WTrigger3/Filler/173/-/-/Zuberoatik etorri dira turista hauek nan nan/Abs'): 965,
#  np.str_('203/WTrigger3/Filler/174/-/-/Maskararik gabe etorri da pertsona hori ospitalera/Abs'): 966,
#  np.str_('203/WTrigger3/Filler/175/-/-/Europako makroetxalderik handiena Euskal Herrian kokatzen da/Abs'): 967,
#  np.str_('203/WTrigger3/Filler/176/-/-/Presoen gizarteratzea sustauko du Eusko Jaurlaritzak erakunde/Erg'): 968,
#  np.str_('203/WTrigger3/Filler/177/-/-/Arrautzen kolorea aldatzen da animaliaren arabera nan/Abs'): 969,
#  np.str_('203/WTrigger3/Filler/178/-/-/Ekonomiaren hazkundea espero da datorren urterako nan/Abs'): 970,
#  np.str_('203/WTrigger3/Filler/179/-/-/Ideiaz aldatzen duzunean deituko didazu nan nan/Erg'): 971,
#  np.str_('203/WTrigger3/Filler/18/Unamb/-/Maskara honek min handia eragin du nan/Erg'): 972,
#  np.str_('203/WTrigger3/Filler/180/-/-/Errusiako hiriburua Mosku da gaur egun nan/Abs'): 973,
#  np.str_('203/WTrigger3/Filler/181/-/-/Kontzertuko bigarren orduan jo dute abesti hori/Erg'): 974,
#  np.str_('203/WTrigger3/Filler/182/-/-/Buruko minagatik joan da urgentzietara agure zaharra/Abs'): 975,
#  np.str_('203/WTrigger3/Filler/183/-/-/Burgosetik etorri den nire laguna da hau/Abs'): 976,
#  np.str_('203/WTrigger3/Filler/184/-/-/Errekaren alboan igaro dute arratsaldea lagunek Oñatin/Erg'): 977,
#  np.str_('203/WTrigger3/Filler/185/-/-/Markizeko kobak bisitatu zituzten arratsaldean nan nan/Erg'): 978,
#  np.str_('203/WTrigger3/Filler/186/-/-/Martari kontauko diot pasatu dena nan nan/Erg'): 979,
#  np.str_('203/WTrigger3/Filler/187/-/-/Liburuaren atzekaldean egin du sinadura idazle ospetsuak/Erg'): 980,
#  np.str_('203/WTrigger3/Filler/188/-/-/Elizaren aurrean egin dute dantza balleteko ikasleek/Erg'): 981,
#  np.str_('203/WTrigger3/Filler/189/-/-/Ikertzailearen eskaerak ezekoa jaso zuen epaimahaian nan/Erg'): 982,
#  np.str_('203/WTrigger3/Filler/19/Unamb/-/Postari horrek kaxa bat banatu du nan/Erg'): 983,
#  np.str_('203/WTrigger3/Filler/190/-/-/Hilketaren egunean jaso zuen mezua amonak nan/Erg'): 984,
#  np.str_('203/WTrigger3/Filler/191/-/-/Malagatik heldu da nire lehengusua gaur nan/Abs'): 985,
#  np.str_('203/WTrigger3/Filler/192/-/-/Errekuperatzeko saioetan nabil istripua izan nuenetik nan/Abs'): 986,
#  np.str_('203/WTrigger3/Filler/2/Unamb/-/Guraso hark goxoki garestiena erosi du nan/Erg'): 987,
#  np.str_('203/WTrigger3/Filler/20/Unamb/-/Bikote hark opari piloa ekarri du nan/Erg'): 988,
#  np.str_('203/WTrigger3/Filler/21/Unamb/-/Osaba honek etxe polita eraiki du nan/Erg'): 989,
#  np.str_('203/WTrigger3/Filler/22/Unamb/-/Santu horrek mirakulu sinestezina egin du nan/Erg'): 990,
#  np.str_('203/WTrigger3/Filler/23/Unamb/-/Langile hark botila osoa edan du nan/Erg'): 991,
#  np.str_('203/WTrigger3/Filler/24/Unamb/-/Behi honek zelai osoa zanpatu du nan/Erg'): 992,
#  np.str_('203/WTrigger3/Filler/25/Amb/-/Enpresari hauek miloi bat zor dute nan/Erg'): 993,
#  np.str_('203/WTrigger3/Filler/26/Amb/-/Gizon horiek gaztai zatia erosi dute nan/Erg'): 994,
#  np.str_('203/WTrigger3/Filler/27/Amb/-/Mamu haiek ume txikia ikaratu dute nan/Erg'): 995,
#  np.str_('203/WTrigger3/Filler/28/Amb/-/Mozkor hauek ondasun guztia suntsitu dute nan/Erg'): 996,
#  np.str_('203/WTrigger3/Filler/29/Amb/-/Haur horiek pastel gozoa prestatu dute nan/Erg'): 997,
#  np.str_('203/WTrigger3/Filler/3/Unamb/-/Errege honek laguntzaile leiala ikaratu du nan/Erg'): 998,
#  np.str_('203/WTrigger3/Filler/30/Amb/-/Neska haiek pazientea urgentzietan utzi dute nan/Erg'): 999,
#  np.str_('203/WTrigger3/Filler/31/Amb/-/Iruzurti hauek tranpa galanta egin dute nan/Erg'): 1000,
#  ...}

# %% [markdown]
# Vemos que tenemos ya un array de eventos y un diccionario. El diccionario (estructura 'key':value) se conecta con los eventos en la forma de `'descripción': Evento`.
#
# <br>
#
# <center>
#
# *Profe y ¿Qué son esas descripciones? No entiendo nada*
# ･(>﹏<)
#
# </center>
#
# <br>
#
# Tranquilos, para entender los eventos necesitamos un poco de contexto del estudio que proporcionó la data para este tutorial.
#
# <br>
#
# En la descripción, lo más notorio es una oración en vasco, como "*Influencerrak oso aberats egin dira azken urtean*". Estas oraciones son los estímulos usados en el estudio, alrededor de los cuales quiséramos saber si hay algún potencial.
#
# <br>
#
# Tenemos también datos como `Filler` `Critical` `Amb` `Erg`.
#
# <br>
#
# Una oración `Filler` es aquella que se presentó como "relleno" en el experimento. Es decir, no deberíamos encontrar necesariamente potenciales alrededor de ellas. En contraste está el `Critical`, que sí señala oraciones que posiblemente provocarían un potencial.
#
# <br>
#
# Lo que sigue son características de las oraciones. `Amb`/`Unamb` si la oración fue ambigua o no ambigua. `Erg`/`Abs` si la oración fue ergativa o absolutiva.
#
# <br>
#
# Lo más críptico podrían ser las etiquetas como `WTrigger1`. En realidad, es algo bastante simple; el experimento marcó un evento por cada palabra de la oración. El Trigger nos dice qué palabra fue: `WTrigger1` para la primera, `WTrigger2` para la segunda, etc.
#
# <br>
#
# Podemos explorar como se corresponden, en el output anterior encontramos que los primeros eventos eran:
#
# <code>
# [  16254,       0,     336],</code><br>
# <code>[  16916,       0,     691],</code><br>
# <code>[  17133,       0,    1075]
# </code>
#
# <br>
#
# Si la lógica es `[tiempo, 0, evento]`, entonces los números 336, 691 y 1075 deberían ser las primeras 3 palabras de una misma oración. Podemos comprobar esto mediante un for loop en el diccionario `annotations`.

# %%
#Probemos el orden

values_to_check=[336, 691, 1075]

for key, value in annotations.items():
  if value in values_to_check:
    print(f"evento{value}: {key}")
# Out:
# evento336: 200/WTriggerFix/Critical/125/Amb/2/Politikari horiek guztiz ezkutuan dimititu dute amarruarengatik/Erg
# evento691: 203/WTrigger1/Critical/125/Amb/2/Politikari horiek guztiz ezkutuan dimititu dute amarruarengatik/Erg
# evento1075: 204/WTrigger2/Critical/125/Amb/2/Politikari horiek guztiz ezkutuan dimititu dute amarruarengatik/Erg

# %% [markdown]
# Con los eventos, podemos pasar a crear epochs. Las epochs son como cortes en la señal de un EEG, los eventos nos van a indicar dónde cortamos. Por defecto, MNE interpretará que el evento siempre es el tiempo 0, así que nosotros tenemos que indicar el valor alrededor de 0, es decir, el tiempo antes y después en el que queremos el corte.
#
# <br>
#
# <table>
#   <tr><th colspan="2" align="left">Función: <strong>mne.Epochs</strong></strong>
#   </strong></strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.Epochs.html"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#
#
#   </th></tr>
#
# <br>
# <tr><td>raw</td><td>El archivo de la señal continua. En este caso, está dentro de nuestros diccionarios. </td></tr>
# <tr><td>events</td><td>Nuestro array de eventos con forma [1,0,1]. </td></tr>
# <tr><td>events_id</td><td>Diccionario donde las keys son strings y los values event codes. </td></tr>
# <tr><td>tmin</td><td>Si el evento es el tiempo 0, el "tmin" es el tiempo antes del 0. Marcamos el inicio del corte (normalmente es negativo). </td></tr>
# <tr><td>tmax</td><td>Marcamos el fin del corte. </td></tr>
# <tr><td>baseline</td><td>Se usa para aplicar una línea base. Por default la aplica, tenemos que decirle "None" para que no lo haga. </td></tr>
# <tr><td>preload</td><td>Cargar el objeto en la memoria RAM. "True" porque queremos hacer operaciones con los epochs. </td></tr>
# <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
# <td colspan="2">
# Objeto nuevo mne.Epochs.
# </table>

# %%
epochs={}
for sub, eeg in eeg_labeled.items():
    events_iteration, annotations_iteration= mne.events_from_annotations(eeg)
    #Construir epochs
    epochs_object= mne.Epochs(
        raw=eeg, #objeto de señal
        events=events_iteration, #
        event_id=annotations_iteration, #
        tmin=-0.1, #se delimita el corte en el tiempo
        tmax=1,
        baseline=None, #No aplicamos una linea base (modifica la epoch).
        preload=True #Importante si queremos seguir preprocesando (se carga el archivo en la RAM)
        )
    epochs[sub]=epochs_object
# Out:
# Used Annotations descriptions: [np.str_('1/WTrigger1/Critical/1/Amb/1/Aizkolari hauek gaur goizean iragan dira Bilbotik/Abs'), np.str_('1/WTrigger1/Critical/101/Amb/1/Sorgin horiek hiru orduz ezkutatu dira etxolan/Abs'), np.str_('1/WTrigger1/Critical/105/Amb/1/Aita haiek seme-alaben kustodiagatik arduratu dira gaur/Abs'), np.str_('1/WTrigger1/Critical/109/Amb/1/Testigu hauek oso bizkor ailegatu dira epaitegira/Abs'), np.str_('1/WTrigger1/Critical/113/Amb/1/Jakintsu horiek denbora luzez atzeratu dira bidaian/Abs'), np.str_('1/WTrigger1/Critical/117/Amb/1/Hippy haiek diru gutxirekin bueltatu dira Ameriketatik/Abs'), np.str_('1/WTrigger1/Critical/121/Amb/1/Haur hauek oporraldi garaian murgildu dira uztailean/Abs'), np.str_('1/WTrigger1/Critical/125/Amb/1/Politikari horiek guztiz ezkutuan aberastu dira amarruarekin/Abs'), np.str_('1/WTrigger1/Critical/129/Amb/1/Jokalari haiek hasi orduko aztoratu dira zelaian/Abs'), np.str_('1/WTrigger1/Critical/13/Amb/1/Ikasle hauek eguerdi inguruan erori dira ikasgelan/Abs'), np.str_('1/WTrigger1/Critical/133/Amb/1/Soprano hauek hilero hilero mozkortu dira aurten/Abs'), np.str_('1/WTrigger1/Critical/137/Amb/1/Dantzari horiek Arriagako eszenatokian lesionatu dira goizean/Abs'), np.str_('1/WTrigger1/Critical/141/Amb/1/Mutiko haiek amonaren alboan koskortu dira umetatik/Abs'), np.str_('1/WTrigger1/Critical/145/Amb/1/Militar hauek Kubako gerrillan desagertu dira aurten/Abs'), np.str_('1/WTrigger1/Critical/149/Amb/1/Tertuliakide horiek gogo biziz ahalegindu dira laguntzen/Abs'), np.str_('1/WTrigger1/Critical/153/Amb/1/Boluntario haiek euren artean haserretu dira bileran/Abs'), np.str_('1/WTrigger1/Critical/157/Amb/1/Arraunlari hauek itsaso zabalean hondoratu dira goizaldean/Abs'), np.str_('1/WTrigger1/Critical/161/Amb/1/Foruzain horiek kuriositate handiz gerturartu dira istripura/Abs'), np.str_('1/WTrigger1/Critical/165/Amb/1/Masajista haiek entrenatzailearen esanetara belaunikatu dira zelaian/Abs'), np.str_('1/WTrigger1/Critical/169/Amb/1/Intsumiso hauek igandeko hauteskundeetan abstenitu dira berriro/Abs'), np.str_('1/WTrigger1/Critical/17/Amb/1/Manifestari horiek gogoz kontra eseri dira bileran/Abs'), np.str_('1/WTrigger1/Critical/173/Amb/1/Erretiratu horiek goizeko ibilaldian irristatu dira lakuan/Abs'), np.str_('1/WTrigger1/Critical/177/Amb/1/Ikertzaile haiek itsasoko espedizioan zorabiatu dira proiektuan/Abs'), np.str_('1/WTrigger1/Critical/181/Amb/1/Zauritu hauek ospitaleko logelan iratzartu dira gaur/Abs'), np.str_('1/WTrigger1/Critical/185/Amb/1/Famatu horiek telebistako saioan berragertu dira oraingoan/Abs'), np.str_('1/WTrigger1/Critical/189/Amb/1/Lapur haiek Ondarruko portuan desorientatu dira iluntzean/Abs'), np.str_('1/WTrigger1/Critical/21/Amb/1/Baserritar haiek mendiko zelaiez jabetu dira arratsaldean/Abs'), np.str_('1/WTrigger1/Critical/25/Amb/1/Zirujau hauek benetan izugarri poztu dira albistearekin/Abs'), np.str_('1/WTrigger1/Critical/29/Amb/1/Haurtxo horiek oso pozik oheratu dira iluntzean/Abs'), np.str_('1/WTrigger1/Critical/33/Amb/1/Pintore haiek pandemia garaian ahuldu dira gehien/Abs'), np.str_('1/WTrigger1/Critical/37/Amb/1/Neskatila hauek arratsalde amaieran hoztu dira parkean/Abs'), np.str_('1/WTrigger1/Critical/41/Amb/1/Bisitari horiek atsedenaren ostean zutitu dira freskatzeko/Abs'), np.str_('1/WTrigger1/Critical/45/Amb/1/Ingeniari haiek laneko bidaian nekatu dira gehienbat/Abs'), np.str_('1/WTrigger1/Critical/49/Amb/1/Ikerlari hauek espero gabe zahartu dira lanean/Abs'), np.str_('1/WTrigger1/Critical/5/Amb/1/Preso horiek laguntzei esker irten dira kartzelatik/Abs'), np.str_('1/WTrigger1/Critical/53/Amb/1/Alaba horiek amonaren altzoan lasaitu dira goizean/Abs'), np.str_('1/WTrigger1/Critical/57/Amb/1/Feminista haiek erasotzailearen aurka ausartu dira tabernan/Abs'), np.str_('1/WTrigger1/Critical/61/Amb/1/Pianista hauek gaurko saioan kezkatu dira zuzendariarekin/Abs'), np.str_('1/WTrigger1/Critical/65/Amb/1/Parroko horiek aita-santuaren hitzekin harrotu dira Vatikanoan/Abs ...
# Not setting metadata
# 2304 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2304 events and 276 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: [np.str_('1/WTrigger1/Critical/10/Amb/1/Diseinatzaile hauek esperantza handiz jaitsi dira sariketara/Abs'), np.str_('1/WTrigger1/Critical/102/Amb/1/Bezero haiek denbora luzez ezkutatu dira saltokian/Abs'), np.str_('1/WTrigger1/Critical/106/Amb/1/Kontseilari hauek pandemia egoeragatik arduratu dira prentsaurrean/Abs'), np.str_('1/WTrigger1/Critical/110/Amb/1/Ekologista horiek urduritasun itxuraz ailegatu dira kongresura/Abs'), np.str_('1/WTrigger1/Critical/114/Amb/1/Funtzionario haiek espero bezala atzeratu dira oporretan/Abs'), np.str_('1/WTrigger1/Critical/118/Amb/1/Aktore hauek guztiz burumakur bueltatu dira grabaziotik/Abs'), np.str_('1/WTrigger1/Critical/122/Amb/1/Zinegotzi horiek jaien astean murgildu dira Gasteizen/Abs'), np.str_('1/WTrigger1/Critical/126/Amb/1/Lider haiek urteetan zehar aberastu dira bilkurekin/Abs'), np.str_('1/WTrigger1/Critical/130/Amb/1/Youtuber hauek urtero bezala aztoratu dira partiduarekin/Abs'), np.str_('1/WTrigger1/Critical/134/Amb/1/Musikari horiek bazkal ostean mozkortu dira frontoian/Abs'), np.str_('1/WTrigger1/Critical/138/Amb/1/Futbolzale haiek hamabiak aldera lesionatu dira plazan/Abs'), np.str_('1/WTrigger1/Critical/14/Amb/1/Boxeolari horiek azken unean erori dira lurrera/Abs'), np.str_('1/WTrigger1/Critical/142/Amb/1/Neskatila hauek ziztu bizian koskortu dira futbolean/Abs'), np.str_('1/WTrigger1/Critical/146/Amb/1/Aurkezle horiek telebistako estudioetan desagertu dira iluntzean/Abs'), np.str_('1/WTrigger1/Critical/150/Amb/1/Adiskide haiek modu ezkutuan ahalegindu dira kopiatzen/Abs'), np.str_('1/WTrigger1/Critical/154/Amb/1/Atezain hauek berebiziko energiaz haserretu dira partiduan/Abs'), np.str_('1/WTrigger1/Critical/158/Amb/1/Gerlari horiek urruneko itsasotan hondoratu dira zoritxarrez/Abs'), np.str_('1/WTrigger1/Critical/162/Amb/1/Langile haiek prestutasun handiz gerturartu dira taldera/Abs'), np.str_('1/WTrigger1/Critical/166/Amb/1/Langabe hauek udaletxearen ondoan belaunikatu dira manifestazioan/Abs'), np.str_('1/WTrigger1/Critical/170/Amb/1/Bazkide horiek osteguneko batzordean abstenitu dira giroagatik/Abs'), np.str_('1/WTrigger1/Critical/174/Amb/1/Poeta haiek unibertsitateko aretoan irristatu dira gauean/Abs'), np.str_('1/WTrigger1/Critical/178/Amb/1/Emakume hauek beroaren eraginez zorabiatu dira ibilaldian/Abs'), np.str_('1/WTrigger1/Critical/18/Amb/1/Frantziar haiek ilusio handiz eseri dira jatetxean/Abs'), np.str_('1/WTrigger1/Critical/182/Amb/1/Haur horiek gurasoen laguntzaz iratzartu dira lehiaketarako/Abs'), np.str_('1/WTrigger1/Critical/186/Amb/1/Gizon haiek gauerdi inguruan berragertu dira tabernan/Abs'), np.str_('1/WTrigger1/Critical/190/Amb/1/Biolinista hauek nazioarteko jaialdian desorientatu dira gauean/Abs'), np.str_('1/WTrigger1/Critical/2/Amb/1/Mutil horiek guztiz ezkutuan iragan dira baserritik/Abs'), np.str_('1/WTrigger1/Critical/22/Amb/1/Enpresari hauek atsekabe larrian jabetu dira gatazkaz/Abs'), np.str_('1/WTrigger1/Critical/26/Amb/1/Ikusle horiek aldi berean poztu dira musikarekin/Abs'), np.str_('1/WTrigger1/Critical/30/Amb/1/Mendizale haiek nekearen eraginez oheratu dira mendian/Abs'), np.str_('1/WTrigger1/Critical/34/Amb/1/Ume hauek merendolaren ondoren ahuldu dira eguzkipean/Abs'), np.str_('1/WTrigger1/Critical/38/Amb/1/Jubilatu horiek goizalde partean hoztu dira hirian/Abs'), np.str_('1/WTrigger1/Critical/42/Amb/1/Kirolzale haiek partidua amaitzean zutitu dira azkenean/Abs'), np.str_('1/WTrigger1/Critical/46/Amb/1/Maisu hauek ikastaro horretan nekatu dira asteburuan/Abs'), np.str_('1/WTrigger1/Critical/50/Amb/1/Aktore horiek oso ongi zahartu dira telesailean/Abs'), np.str_('1/WTrigger1/Critical/54/Amb/1/Grebalari haiek manifestazio bukaeran lasaitu dira kalean/Abs'), np.str_('1/WTrigger1/Critical/58/Amb/1/Eskalatzaile hauek Udalaitz igotzen ausartu dira goizean/Abs'), np.str_('1/WTrigger1/Critical/6/Amb/1/Kamioilari haiek lasai asko irten dira errepidera/Abs'), np.str_('1/WTrigger1/Critical/62/Amb/1/Mediku horiek birusaren  ...
# Not setting metadata
# 2304 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2304 events and 276 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: [np.str_('1/WTrigger1/Critical/100/Amb/1/Abokatu hauek hamaikak aldera hurbildu dira epaitegira/Abs'), np.str_('1/WTrigger1/Critical/104/Amb/1/Atleta horiek oraintxe bertan ezkutatu dira harmailetan/Abs'), np.str_('1/WTrigger1/Critical/108/Amb/1/Tutore haiek denbora luzez arduratu dira arazoaz/Abs'), np.str_('1/WTrigger1/Critical/112/Amb/1/Alkate hauek harrokeria handiz ailegatu dira udaletxera/Abs'), np.str_('1/WTrigger1/Critical/116/Amb/1/Ordezkari horiek istiluen ondorioz atzeratu dira batzordean/Abs'), np.str_('1/WTrigger1/Critical/12/Amb/1/Diputatu haiek urte luzez jaitsi dira herritarrengana/Abs'), np.str_('1/WTrigger1/Critical/120/Amb/1/Apezpiku haiek neke aurpegiaz bueltatu dira Erromatik/Abs'), np.str_('1/WTrigger1/Critical/124/Amb/1/Turista hauek Mexikon barrena murgildu dira abuztuan/Abs'), np.str_('1/WTrigger1/Critical/128/Amb/1/Umorista horiek managerrari esker aberastu dira pelikulekin/Abs'), np.str_('1/WTrigger1/Critical/132/Amb/1/Sukaldari haiek ardoa edanda aztoratu dira elkartean/Abs'), np.str_('1/WTrigger1/Critical/136/Amb/1/Nerabe hauek BBK jaialdian mozkortu dira horrenbeste/Abs'), np.str_('1/WTrigger1/Critical/140/Amb/1/Harakin horiek euren jardunagatik lesionatu dira oraingoan/Abs'), np.str_('1/WTrigger1/Critical/144/Amb/1/Ume haiek musikariz inguratuta koskortu dira herrian/Abs'), np.str_('1/WTrigger1/Critical/148/Amb/1/Txirrindulari hauek hiru egunez desagertu dira Pirinioetan/Abs'), np.str_('1/WTrigger1/Critical/152/Amb/1/Palestinar horiek urteetan zehar ahalegindu dira liberatzen/Abs'), np.str_('1/WTrigger1/Critical/156/Amb/1/Kazetari haiek telefono deian haserretu dira editoreekin/Abs'), np.str_('1/WTrigger1/Critical/16/Amb/1/Gazte hauek kanpuseko aretoan erori dira goizean/Abs'), np.str_('1/WTrigger1/Critical/160/Amb/1/Bidaiari hauek oso leunki hondoratu dira itsasoan/Abs'), np.str_('1/WTrigger1/Critical/164/Amb/1/Pilotu horiek hegazkin bidaian gerturartu dira Donostiara/Abs'), np.str_('1/WTrigger1/Critical/168/Amb/1/Mandatari haiek elizaren atarian belaunikatu dira goizean/Abs'), np.str_('1/WTrigger1/Critical/172/Amb/1/Lankide hauek taldearekin bat abstenitu dira batzordean/Abs'), np.str_('1/WTrigger1/Critical/176/Amb/1/Modelo horiek takoidun oinetakoekin irristatu dira agerraldian/Abs'), np.str_('1/WTrigger1/Critical/180/Amb/1/Mutil haiek azkenaldian gehiegi zorabiatu dira tamalez/Abs'), np.str_('1/WTrigger1/Critical/184/Amb/1/Laguntzaile hauek goizean goiz iratzartu dira muntaketarako/Abs'), np.str_('1/WTrigger1/Critical/188/Amb/1/Basozain horiek baserriko lursailetan berragertu dira goizean/Abs'), np.str_('1/WTrigger1/Critical/192/Amb/1/Erreportari haiek denbora luzez desorientatu dira telebistan/Abs'), np.str_('1/WTrigger1/Critical/20/Amb/1/Kantari horiek piano ondoan eseri dira kontzertuan/Abs'), np.str_('1/WTrigger1/Critical/24/Amb/1/Politikari haiek urtebete ostean jabetu dira arazoaz/Abs'), np.str_('1/WTrigger1/Critical/28/Amb/1/Kimikari hauek aurkikuntza berriarekin poztu dira laborategian/Abs'), np.str_('1/WTrigger1/Critical/32/Amb/1/Erizain horiek berebiziko tristuraz oheratu dira pandemian/Abs'), np.str_('1/WTrigger1/Critical/36/Amb/1/Ezagun haiek abiadura azkarregian ahuldu dira tamalez/Abs'), np.str_('1/WTrigger1/Critical/4/Amb/1/Irakasle hauek poz handiz iragan dira eskolatik/Abs'), np.str_('1/WTrigger1/Critical/40/Amb/1/Hezitzaile hauek parkean eserita hoztu dira iluntzean/Abs'), np.str_('1/WTrigger1/Critical/44/Amb/1/Ikaskide horiek txirrina entzutean zutitu dira klasean/Abs'), np.str_('1/WTrigger1/Critical/48/Amb/1/Apaiz haiek oso goiz nekatu dira Arantzazun/Abs'), np.str_('1/WTrigger1/Critical/52/Amb/1/Pilotari hauek nahiko goiz zahartu dira egiazki/Abs'), np.str_('1/WTrigger1/Critical/56/Amb/1/Langile horiek bitartekariei esker lasaitu dira lanean/Abs'), np.str_('1/WTrigger1/Critical/60/Amb/1/Artista haiek traje modernoekin ausartu dira plazan/Abs'), np.str_('1/WTrigger1/Critical/64/Amb/1/Errefuxiatu hauek benetan sutsuki kezkatu dira protestagati ...
# Not setting metadata
# 2304 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2304 events and 276 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: [np.str_('1/WTrigger1/Critical/1/Amb/1/Aizkolari hauek gaur goizean iragan dira Bilbotik/Abs'), np.str_('1/WTrigger1/Critical/101/Amb/1/Sorgin horiek hiru orduz ezkutatu dira etxolan/Abs'), np.str_('1/WTrigger1/Critical/105/Amb/1/Aita haiek seme-alaben kustodiagatik arduratu dira gaur/Abs'), np.str_('1/WTrigger1/Critical/109/Amb/1/Testigu hauek oso bizkor ailegatu dira epaitegira/Abs'), np.str_('1/WTrigger1/Critical/113/Amb/1/Jakintsu horiek denbora luzez atzeratu dira bidaian/Abs'), np.str_('1/WTrigger1/Critical/117/Amb/1/Hippy haiek diru gutxirekin bueltatu dira Ameriketatik/Abs'), np.str_('1/WTrigger1/Critical/121/Amb/1/Haur hauek oporraldi garaian murgildu dira uztailean/Abs'), np.str_('1/WTrigger1/Critical/125/Amb/1/Politikari horiek guztiz ezkutuan aberastu dira amarruarekin/Abs'), np.str_('1/WTrigger1/Critical/129/Amb/1/Jokalari haiek hasi orduko aztoratu dira zelaian/Abs'), np.str_('1/WTrigger1/Critical/13/Amb/1/Ikasle hauek eguerdi inguruan erori dira ikasgelan/Abs'), np.str_('1/WTrigger1/Critical/133/Amb/1/Soprano hauek hilero hilero mozkortu dira aurten/Abs'), np.str_('1/WTrigger1/Critical/137/Amb/1/Dantzari horiek Arriagako eszenatokian lesionatu dira goizean/Abs'), np.str_('1/WTrigger1/Critical/141/Amb/1/Mutiko haiek amonaren alboan koskortu dira umetatik/Abs'), np.str_('1/WTrigger1/Critical/145/Amb/1/Militar hauek Kubako gerrillan desagertu dira aurten/Abs'), np.str_('1/WTrigger1/Critical/149/Amb/1/Tertuliakide horiek gogo biziz ahalegindu dira laguntzen/Abs'), np.str_('1/WTrigger1/Critical/153/Amb/1/Boluntario haiek euren artean haserretu dira bileran/Abs'), np.str_('1/WTrigger1/Critical/157/Amb/1/Arraunlari hauek itsaso zabalean hondoratu dira goizaldean/Abs'), np.str_('1/WTrigger1/Critical/161/Amb/1/Foruzain horiek kuriositate handiz gerturartu dira istripura/Abs'), np.str_('1/WTrigger1/Critical/165/Amb/1/Masajista haiek entrenatzailearen esanetara belaunikatu dira zelaian/Abs'), np.str_('1/WTrigger1/Critical/169/Amb/1/Intsumiso hauek igandeko hauteskundeetan abstenitu dira berriro/Abs'), np.str_('1/WTrigger1/Critical/17/Amb/1/Manifestari horiek gogoz kontra eseri dira bileran/Abs'), np.str_('1/WTrigger1/Critical/173/Amb/1/Erretiratu horiek goizeko ibilaldian irristatu dira lakuan/Abs'), np.str_('1/WTrigger1/Critical/177/Amb/1/Ikertzaile haiek itsasoko espedizioan zorabiatu dira proiektuan/Abs'), np.str_('1/WTrigger1/Critical/181/Amb/1/Zauritu hauek ospitaleko logelan iratzartu dira gaur/Abs'), np.str_('1/WTrigger1/Critical/185/Amb/1/Famatu horiek telebistako saioan berragertu dira oraingoan/Abs'), np.str_('1/WTrigger1/Critical/189/Amb/1/Lapur haiek Ondarruko portuan desorientatu dira iluntzean/Abs'), np.str_('1/WTrigger1/Critical/21/Amb/1/Baserritar haiek mendiko zelaiez jabetu dira arratsaldean/Abs'), np.str_('1/WTrigger1/Critical/25/Amb/1/Zirujau hauek benetan izugarri poztu dira albistearekin/Abs'), np.str_('1/WTrigger1/Critical/29/Amb/1/Haurtxo horiek oso pozik oheratu dira iluntzean/Abs'), np.str_('1/WTrigger1/Critical/33/Amb/1/Pintore haiek pandemia garaian ahuldu dira gehien/Abs'), np.str_('1/WTrigger1/Critical/37/Amb/1/Neskatila hauek arratsalde amaieran hoztu dira parkean/Abs'), np.str_('1/WTrigger1/Critical/41/Amb/1/Bisitari horiek atsedenaren ostean zutitu dira freskatzeko/Abs'), np.str_('1/WTrigger1/Critical/45/Amb/1/Ingeniari haiek laneko bidaian nekatu dira gehienbat/Abs'), np.str_('1/WTrigger1/Critical/49/Amb/1/Ikerlari hauek espero gabe zahartu dira lanean/Abs'), np.str_('1/WTrigger1/Critical/5/Amb/1/Preso horiek laguntzei esker irten dira kartzelatik/Abs'), np.str_('1/WTrigger1/Critical/53/Amb/1/Alaba horiek amonaren altzoan lasaitu dira goizean/Abs'), np.str_('1/WTrigger1/Critical/57/Amb/1/Feminista haiek erasotzailearen aurka ausartu dira tabernan/Abs'), np.str_('1/WTrigger1/Critical/61/Amb/1/Pianista hauek gaurko saioan kezkatu dira zuzendariarekin/Abs'), np.str_('1/WTrigger1/Critical/65/Amb/1/Parroko horiek aita-santuaren hitzekin harrotu dira Vatikanoan/Abs ...
# Not setting metadata
# 2304 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2304 events and 276 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: [np.str_('1/WTrigger1/Critical/103/Amb/1/Bitartekari hauek mehatxuen ondorioz ezkutatu dira etxean/Abs'), np.str_('1/WTrigger1/Critical/107/Amb/1/Gitarrista horiek managerrekin batera arduratu dira publikoaz/Abs'), np.str_('1/WTrigger1/Critical/11/Amb/1/Kirolari horiek luzaketen ostean jaitsi dira kantxara/Abs'), np.str_('1/WTrigger1/Critical/111/Amb/1/Ekintzaile haiek kezka handiz ailegatu dira bilerara/Abs'), np.str_('1/WTrigger1/Critical/115/Amb/1/Ikasle hauek ordu erdiz atzeratu dira jolastorduan/Abs'), np.str_('1/WTrigger1/Critical/119/Amb/1/Diruzain horiek oso damututa bueltatu dira kargura/Abs'), np.str_('1/WTrigger1/Critical/123/Amb/1/Misiolari haiek indigenen artean murgildu dira Hondurasen/Abs'), np.str_('1/WTrigger1/Critical/127/Amb/1/Farmazialari hauek txertoei esker aberastu dira Alemanian/Abs'), np.str_('1/WTrigger1/Critical/131/Amb/1/Tronpetista horiek zuzendaria sartzean aztoratu dira arratsaldean/Abs'), np.str_('1/WTrigger1/Critical/135/Amb/1/Tabernari haiek herriko festetan mozkortu dira gazteekin/Abs'), np.str_('1/WTrigger1/Critical/139/Amb/1/Korrikalari hauek eguzki galdatan lesionatu dira mendian/Abs'), np.str_('1/WTrigger1/Critical/143/Amb/1/Gaztetxo horiek konturatu gabe koskortu dira lanean/Abs'), np.str_('1/WTrigger1/Critical/147/Amb/1/Lagun haiek besteen ezkutuan desagertu dira bazkaritik/Abs'), np.str_('1/WTrigger1/Critical/15/Amb/1/Pirata haiek ardoz lepo erori dira itsasora/Abs'), np.str_('1/WTrigger1/Critical/151/Amb/1/Pertikalari hauek kemen handiz ahalegindu dira hobetzen/Abs'), np.str_('1/WTrigger1/Critical/155/Amb/1/Detektibe horiek tarte luzez haserretu dira poliziarekin/Abs'), np.str_('1/WTrigger1/Critical/159/Amb/1/Alargun haiek galeraren saminaz hondoratu dira tanatorioan/Abs'), np.str_('1/WTrigger1/Critical/163/Amb/1/Bizilagun hauek kaleko zaratengatik gerturartu dira balkoira/Abs'), np.str_('1/WTrigger1/Critical/167/Amb/1/Fededun horiek apaizaren hitzekin belaunikatu dira mezetan/Abs'), np.str_('1/WTrigger1/Critical/171/Amb/1/Filosofo haiek konbentzimendu osoz abstenitu dira hauteskundeetan/Abs'), np.str_('1/WTrigger1/Critical/175/Amb/1/Patinatzaile hauek lehiaketan gaizki irristatu dira tamalez/Abs'), np.str_('1/WTrigger1/Critical/179/Amb/1/Neska horiek eguzki izpiekin zorabiatu dira eguerdian/Abs'), np.str_('1/WTrigger1/Critical/183/Amb/1/Ezezagun haiek ordu txikitan iratzartu dira zubipean/Abs'), np.str_('1/WTrigger1/Critical/187/Amb/1/Iheslari hauek ikerketa berrian berragertu dira ustekabean/Abs'), np.str_('1/WTrigger1/Critical/19/Amb/1/Gaixo hauek ikarak jota eseri dira anbulantzian/Abs'), np.str_('1/WTrigger1/Critical/191/Amb/1/Mendizale horiek gaua iristean desorientatu dira Aizkorrin/Abs'), np.str_('1/WTrigger1/Critical/23/Amb/1/Bertsolari horiek nagusitasun osoz jabetu dira plazaz/Abs'), np.str_('1/WTrigger1/Critical/27/Amb/1/Zuzendari haiek ustekabearen ondorioz poztu dira goizean/Abs'), np.str_('1/WTrigger1/Critical/3/Amb/1/Suhiltzaile haiek asko kostata iragan dira istriputik/Abs'), np.str_('1/WTrigger1/Critical/31/Amb/1/Zerbitzari hauek ordu txikitan oheratu dira festetan/Abs'), np.str_('1/WTrigger1/Critical/35/Amb/1/Atso horiek astiro astiro ahuldu dira erresidentzian/Abs'), np.str_('1/WTrigger1/Critical/39/Amb/1/Bidaiari haiek haize bortitzarekin hoztu dira Pirinioetan/Abs'), np.str_('1/WTrigger1/Critical/43/Amb/1/Agure hauek patxada handiz zutitu dira mahatik/Abs'), np.str_('1/WTrigger1/Critical/47/Amb/1/Mutiko horiek gimnasia klasean nekatu dira eguerdian/Abs'), np.str_('1/WTrigger1/Critical/51/Amb/1/Epaile haiek hikamiken ondorioz zahartu dira horrela/Abs'), np.str_('1/WTrigger1/Critical/55/Amb/1/Txirrindulari hauek asko kostata lasaitu dira azkenean/Abs'), np.str_('1/WTrigger1/Critical/59/Amb/1/Eskiatzaile horiek mendia zeharkatzen ausartu dira gaur/Abs'), np.str_('1/WTrigger1/Critical/63/Amb/1/Marinel haiek trumoi hotsarekin kezkatu dira gauean/Abs'), np.str_('1/WTrigger1/Critical/67/Amb/1/Esploratzaile hauek kapitainaren mezuekin harro ...
# Not setting metadata
# 2304 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2304 events and 276 original time points ...
# 0 bad epochs dropped

# %% [markdown]
# Además, en el experimento que intentamos replicar, las palabras clave son los verbos, que se encuentran siempre en la posición 5 `WTrigger5`.
#
# <br>
#
# Para esto el objeto de eventos en MNE tiene un       <a href="https://mne.tools/stable/generated/mne.Epochs.html#mne.Epochs.__getitem__"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       atributo</a> muy útil que nos permite acceder a los objetos mediante sus anotaciones, como si fuese un diccionario.
#
#
# <br>
#
# Entonces, llamar al objeto como `epoch['WTrigger5']` nos ayudará a recuperar todos los cortes alrededor de los verbos, en todas las oraciones, en todas las condiciones.

# %%
epochs_filtered={}
for sub, eeg in epochs.items():
    selected_epochs=eeg['WTrigger5']
    epochs_filtered[sub]=selected_epochs
epochs_filtered
# Out:
# {'01': <Epochs | 384 events (all good), -0.1 – 1 s (baseline off), ~25.9 MiB, data loaded,
#   np.str_('205/WTrigger5/Critical/1/Amb/1/Aizkolari hauek gaur goizean iragan dira Bilbotik/Abs'): 1
#   np.str_('205/WTrigger5/Critical/10/Unamb/4/Diseinatzaile honek esperantza handiz bozkatu du sariketan/Erg'): 1
#   np.str_('205/WTrigger5/Critical/100/Amb/2/Abokatu hauek hamaikak aldera deklaratu dute epaitegian/Erg'): 1
#   np.str_('205/WTrigger5/Critical/101/Amb/1/Sorgin horiek hiru orduz ezkutatu dira etxolan/Abs'): 1
#   np.str_('205/WTrigger5/Critical/102/Unamb/4/Bezero hark denbora luzez argudiatu du saltokian/Erg'): 1
#   np.str_('205/WTrigger5/Critical/103/Unamb/3/Bitartekari hau mehatxuen ondorioz ezkutatu da etxean/Abs'): 1
#   np.str_('205/WTrigger5/Critical/104/Amb/2/Atleta horiek oraintxe bertan begiratu dute harmailarantz/Erg'): 1
#   np.str_('205/WTrigger5/Critical/105/Amb/1/Aita haiek seme-alaben kustodiagatik arduratu dira gaur/Abs'): 1
#   np.str_('205/WTrigger5/Critical/106/Unamb/4/Kontseilari honek pandemia egoeragatik deklaratu du prentsaurrean/Erg'): 1
#   np.str_('205/WTrigger5/Critical/107/Unamb/3/Gitarrista hori managerrekin batera arduratu da publikoaz/Abs'): 1
#   and 374 more events ...>,
#  '02': <Epochs | 384 events (all good), -0.1 – 1 s (baseline off), ~25.9 MiB, data loaded,
#   np.str_('205/WTrigger5/Critical/1/Amb/2/Aizkolari hauek gaur goizean jokatu dute Bilbon/Erg'): 1
#   np.str_('205/WTrigger5/Critical/10/Amb/1/Diseinatzaile hauek esperantza handiz jaitsi dira sariketara/Abs'): 1
#   np.str_('205/WTrigger5/Critical/100/Unamb/3/Abokatu hau hamaikak aldera hurbildu da epaitegira/Abs'): 1
#   np.str_('205/WTrigger5/Critical/101/Amb/2/Sorgin horiek hiru orduz pentsatu dute etxolan/Erg'): 1
#   np.str_('205/WTrigger5/Critical/102/Amb/1/Bezero haiek denbora luzez ezkutatu dira saltokian/Abs'): 1
#   np.str_('205/WTrigger5/Critical/103/Unamb/4/Bitartekari honek mehatxuen ondorioz deklaratu du etxetik/Erg'): 1
#   np.str_('205/WTrigger5/Critical/104/Unamb/3/Atleta hori oraintxe bertan ezkutatu da harmailetan/Abs'): 1
#   np.str_('205/WTrigger5/Critical/105/Amb/2/Aita haiek seme-alaben kustodiagatik argudiatu dute gaur/Erg'): 1
#   np.str_('205/WTrigger5/Critical/106/Amb/1/Kontseilari hauek pandemia egoeragatik arduratu dira prentsaurrean/Abs'): 1
#   np.str_('205/WTrigger5/Critical/107/Unamb/4/Gitarrista horrek managerrekin batera begiratu du publikorantz/Erg'): 1
#   and 374 more events ...>,
#  '04': <Epochs | 384 events (all good), -0.1 – 1 s (baseline off), ~25.9 MiB, data loaded,
#   np.str_('205/WTrigger5/Critical/1/Unamb/4/Aizkolari honek gaur goizean jokatu du Bilbon/Erg'): 1
#   np.str_('205/WTrigger5/Critical/10/Unamb/3/Diseinatzaile hau esperantza handiz jaitsi da sariketara/Abs'): 1
#   np.str_('205/WTrigger5/Critical/100/Amb/1/Abokatu hauek hamaikak aldera hurbildu dira epaitegira/Abs'): 1
#   np.str_('205/WTrigger5/Critical/101/Unamb/4/Sorgin horrek hiru orduz pentsatu du etxolan/Erg'): 1
#   np.str_('205/WTrigger5/Critical/102/Unamb/3/Bezero hura denbora luzez ezkutatu da saltokian/Abs'): 1
#   np.str_('205/WTrigger5/Critical/103/Amb/2/Bitartekari hauek mehatxuen ondorioz deklaratu dute etxetik/Erg'): 1
#   np.str_('205/WTrigger5/Critical/104/Amb/1/Atleta horiek oraintxe bertan ezkutatu dira harmailetan/Abs'): 1
#   np.str_('205/WTrigger5/Critical/105/Unamb/4/Aita hark seme-alaben kustodiagatik argudiatu du gaur/Erg'): 1
#   np.str_('205/WTrigger5/Critical/106/Unamb/3/Kontseilari hau pandemia egoeragatik arduratu da prentsaurrean/Abs'): 1
#   np.str_('205/WTrigger5/Critical/107/Amb/2/Gitarrista horiek managerrekin batera begiratu dute publikorantz/Erg'): 1
#   and 374 more events ...>,
#  '05': <Epochs | 384 events (all good), -0.1 – 1 s (baseline off), ~25.9 MiB, data loaded,
#   np.str_('205/WTrigger5/Critical/1/Amb/1/Aizkolari hauek gaur goizean iragan dira Bilbotik/Abs'): 1
#   np.str_('205/WTrigger5/Critical/10/Unamb/4/Diseinatzaile honek esperantza handiz bozkatu du sariketan/Erg'): 1
#   np.str_('205/WTrigger5/Critical/100/Amb/2/Abokatu hauek hamaikak aldera deklaratu dute epaitegian/Erg'): 1
#   np.str_('205/WTrigger5/Critical/101/Amb/1/Sorgin horiek hiru orduz ezkutatu dira etxolan/Abs'): 1
#   np.str_('205/WTrigger5/Critical/102/Unamb/4/Bezero hark denbora luzez argudiatu du saltokian/Erg'): 1
#   np.str_('205/WTrigger5/Critical/103/Unamb/3/Bitartekari hau mehatxuen ondorioz ezkutatu da etxean/Abs'): 1
#   np.str_('205/WTrigger5/Critical/104/Amb/2/Atleta horiek oraintxe bertan begiratu dute harmailarantz/Erg'): 1
#   np.str_('205/WTrigger5/Critical/105/Amb/1/Aita haiek seme-alaben kustodiagatik arduratu dira gaur/Abs'): 1
#   np.str_('205/WTrigger5/Critical/106/Unamb/4/Kontseilari honek pandemia egoeragatik deklaratu du prentsaurrean/Erg'): 1
#   np.str_('205/WTrigger5/Critical/107/Unamb/3/Gitarrista hori managerrekin batera arduratu da publikoaz/Abs'): 1
#   and 374 more events ...>,
#  '23': <Epochs | 384 events (all good), -0.1 – 1 s (baseline off), ~25.9 MiB, data loaded,
#   np.str_('205/WTrigger5/Critical/1/Unamb/3/Aizkolari hau gaur goizean iragan da Bilbotik/Abs'): 1
#   np.str_('205/WTrigger5/Critical/10/Amb/2/Diseinatzaile hauek esperantza handiz bozkatu dute sariketan/Erg'): 1
#   np.str_('205/WTrigger5/Critical/100/Unamb/4/Abokatu honek hamaikak aldera deklaratu du epaitegian/Erg'): 1
#   np.str_('205/WTrigger5/Critical/101/Unamb/3/Sorgin hori hiru orduz ezkutatu da etxolan/Abs'): 1
#   np.str_('205/WTrigger5/Critical/102/Amb/2/Bezero haiek denbora luzez argudiatu dute saltokian/Erg'): 1
#   np.str_('205/WTrigger5/Critical/103/Amb/1/Bitartekari hauek mehatxuen ondorioz ezkutatu dira etxean/Abs'): 1
#   np.str_('205/WTrigger5/Critical/104/Unamb/4/Atleta horrek oraintxe bertan begiratu du harmailarantz/Erg'): 1
#   np.str_('205/WTrigger5/Critical/105/Unamb/3/Aita hura seme-alaben kustodiagatik arduratu da gaur/Abs'): 1
#   np.str_('205/WTrigger5/Critical/106/Amb/2/Kontseilari hauek pandemia egoeragatik deklaratu dute prentsaurrean/Erg'): 1
#   np.str_('205/WTrigger5/Critical/107/Amb/1/Gitarrista horiek managerrekin batera arduratu dira publikoaz/Abs'): 1
#   and 374 more events ...>}

# %% [markdown]
# <h2>Autoreject. La venganza del pre-procesado.</h2>
#
# <br>
#
# Cada decisión dentro el flujo de análisis puede cambiar la señal, así que podríamos decir que antes de obtener un plot o hacer estadística con los voltajes, seguimos procesando.
#
# <br>
#
# A nivel de épocas, también podemos limpiar la señal de artefactos. `Autoreject` es una herramienta integrada a MNE-Python. Su implementación generalmente es más fácil que el ICA, así que no demoraremos mucho en implementarla.
#
# <br>
#
# Lo que hace `Autoreject`, a grandes rasgos, es detectar epochs dañados en base a la amplitud o frecuencia de la señal. Internamente, usa métodos aleatorios para simular cómo sería una epoch "normal" con los datos que tenemos para tener un punto de comparación.
#
# <br>
#
# Además del rechazo, `Autoreject` puede rescatar las epochs dañadas con métodos como la **interpolación**, la cual consiste en reconstruir la señal de un canal en base a los canales cercanos. Antes de descartar una epoch, `Autoreject` siempre intenta rescatarla antes con la interpolación.
#
# <br>
#
# `Autoreject` está diseñado para sólo ser implementado sobre objetos mne.Epochs, en contraste al `ICA`, que puede ser utilizado en señales continuas o epocalizadas. Con todo lo que tenemos, estamos listos para pasar nuestras epochs tal y como están a `Autoreject`
#
# <br>
#
#
# <table>
#   <tr><th colspan="2" align="left">Función: <strong>autoreject.Autoreject</strong>
#
#   </strong>
#       <a href="https://autoreject.github.io/stable/generated/autoreject.AutoReject.html#autoreject.AutoReject"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#
#
#   </th></tr>
#
#
#
#
#
#   <tr><th colspan="1">Parámetros</th><th colspan="1" align="left">Descripción</th></tr>
#   <tr><td>n_interpolate</td><td>Cuántos canales usar para la interpolación. Usaremos [1,2,3,4] para que pruebe interpolar con 1, 2, 3 o 4 canales.</td></tr>
#   <tr><td>random_state</td><td>El seed de aleatoriedad. 7 para la suerte.</td></tr>
#   <tr><td>n_jobs</td><td>Núcleos para procesar en paralelo en la CPU. Para replicabilidad, no usamos procesamiento en paralelo.</td></tr>
#   <tr><td>thresh_method</td><td>El método que queremos que use autoreject para calcular los umbrales de rechazo de las epochs "bayesian_optimization" por default. </td></tr>
#   <tr><td>verbose</td><td>True or False. Determina si queremos que nos de outputs del progreso de la operación.</td></tr>
#   <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
#   <td colspan="2">
#   Objeto tipo autoreject.Autoreject.
#   </td>
# </table>

# %%
"""


epochs_autoreject={}
reject_logs={}
for sub, epochs_object in epochs_filtered.items():
    ar = autoreject.AutoReject(
    n_interpolate=[1, 2, 3, 4], #recommended in the documentation
    random_state=7, #Universo 7
    n_jobs=1, ### Esto es recomendado para la replicabilidad, por el parallel processing.
    verbose=False,
    thresh_method="bayesian_optimization")
    epochs_enhanced, reject_log = ar.fit_transform(epochs_object, return_log=True)

    if sub not in epochs_autoreject:
        epochs_autoreject[sub]={}
    epochs_autoreject[sub]=epochs_enhanced
    if sub not in reject_logs:
        reject_logs[sub]={}
    reject_logs[sub]=reject_log



"""

# %%
#@title Black Box_(download after AR)
# %%capture
# !wget "https://drive.usercontent.google.com/download?id=1ie6r3Xe-w_Zml7a5CKvhp4zHoAeWLUM2&export=download&confirm" -O afterAR.zip
# !unzip -o afterAR.zip -d /content/

#Esta vez estamos leyendo objetos "epochs", por lo que la librería MNE-BIDS
#No será útil. En lugar de eso, lo haremos manual con "os" y lógica.
#Podemos asumir que ya sabemos dónde se encuentra cada archivo.
#Porque a pesar de que BIDS no lea epochs, sí las hemos guardado.
#En estructura MNE-BIDS.
eeg_dir = os.path.join(os.getcwd(), 'epochsafterAR')
epochs_autoreject = {}
subjects_to_load= ['01', '02', '04', '05', '23']

#iteramos en los sujetos.
for sub in subjects_to_load:
    subject_label=f"sub-{sub}"
    subject_path= os.path.join(eeg_dir, subject_label)
    if not os.path.exists(subject_path):
        print(f"Subject {subject_label} not found")
        continue
    #iteramos en los contenidos de los directorios de la ruta del sujeto.
    for fname in sorted(os.listdir(subject_path)):
        if fname.endswith('_epo.fif'):
            fname_no_ext = fname.replace('_epo.fif', '')
            subject_label, task_name = fname_no_ext.split('_')
            subject_id = subject_label.replace('sub-', '')
            task_name = task_name.replace('task-','')
            fpath = os.path.join(subject_path, fname)
            raw = mne.read_epochs(fpath, preload=True)
            print(f"{subject_label} loaded.")

            epochs_autoreject[sub] = raw

# %% [markdown]
# Luego de rechazar las epochs contaminadas, el siguiente paso es interpolar los canales que pudimos haber rechazado anteriormente (en el primer paso del pre-procesamiento). Para eso utilizaremos el método `.interpolate_bads` de los objetos mne.Epochs.
#
# <br>
#
#
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.interpolate_bads</strong>
#   <br><br>Objeto mne.Epochs
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.Epochs.html#mne.Epochs.interpolate_bads"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#
#
#   </th></tr>
#
#
#
#
#
#   <tr><th colspan="1">Parámetros</th><th colspan="1" align="left">Descripción</th></tr>
#   <tr><td>reset_bads</td><td>True or False. "True" deja de marcar a los canales como "bads" luego de interpolarlos. True en nuestro caso, porque los consideramos reparados.</td></tr>
#
#   <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
#   <td colspan="2">
#   Objeto tipo mne.Epochs con los canales interpolados.
#   </td>
# </table>

# %%
epochs_autoreject
# Out:
# {'01': <EpochsFIF | 248 events (all good), -0.1 – 1 s (baseline off), ~16.8 MiB, data loaded,
#   '205/WTrigger5/Critical/1/Amb/1/Aizkolari hauek gaur goizean iragan dira Bilbotik/Abs': 1
#   '205/WTrigger5/Critical/10/Unamb/4/Diseinatzaile honek esperantza handiz bozkatu du sariketan/Erg': 1
#   '205/WTrigger5/Critical/100/Amb/2/Abokatu hauek hamaikak aldera deklaratu dute epaitegian/Erg': 1
#   '205/WTrigger5/Critical/101/Amb/1/Sorgin horiek hiru orduz ezkutatu dira etxolan/Abs': 0
#   '205/WTrigger5/Critical/102/Unamb/4/Bezero hark denbora luzez argudiatu du saltokian/Erg': 1
#   '205/WTrigger5/Critical/103/Unamb/3/Bitartekari hau mehatxuen ondorioz ezkutatu da etxean/Abs': 1
#   '205/WTrigger5/Critical/104/Amb/2/Atleta horiek oraintxe bertan begiratu dute harmailarantz/Erg': 1
#   '205/WTrigger5/Critical/105/Amb/1/Aita haiek seme-alaben kustodiagatik arduratu dira gaur/Abs': 1
#   '205/WTrigger5/Critical/106/Unamb/4/Kontseilari honek pandemia egoeragatik deklaratu du prentsaurrean/Erg': 1
#   '205/WTrigger5/Critical/107/Unamb/3/Gitarrista hori managerrekin batera arduratu da publikoaz/Abs': 1
#   and 374 more events ...>,
#  '02': <EpochsFIF | 278 events (all good), -0.1 – 1 s (baseline off), ~18.8 MiB, data loaded,
#   '205/WTrigger5/Critical/1/Amb/2/Aizkolari hauek gaur goizean jokatu dute Bilbon/Erg': 1
#   '205/WTrigger5/Critical/10/Amb/1/Diseinatzaile hauek esperantza handiz jaitsi dira sariketara/Abs': 1
#   '205/WTrigger5/Critical/100/Unamb/3/Abokatu hau hamaikak aldera hurbildu da epaitegira/Abs': 0
#   '205/WTrigger5/Critical/101/Amb/2/Sorgin horiek hiru orduz pentsatu dute etxolan/Erg': 1
#   '205/WTrigger5/Critical/102/Amb/1/Bezero haiek denbora luzez ezkutatu dira saltokian/Abs': 1
#   '205/WTrigger5/Critical/103/Unamb/4/Bitartekari honek mehatxuen ondorioz deklaratu du etxetik/Erg': 1
#   '205/WTrigger5/Critical/104/Unamb/3/Atleta hori oraintxe bertan ezkutatu da harmailetan/Abs': 0
#   '205/WTrigger5/Critical/105/Amb/2/Aita haiek seme-alaben kustodiagatik argudiatu dute gaur/Erg': 1
#   '205/WTrigger5/Critical/106/Amb/1/Kontseilari hauek pandemia egoeragatik arduratu dira prentsaurrean/Abs': 1
#   '205/WTrigger5/Critical/107/Unamb/4/Gitarrista horrek managerrekin batera begiratu du publikorantz/Erg': 1
#   and 374 more events ...>,
#  '04': <EpochsFIF | 377 events (all good), -0.1 – 1 s (baseline off), ~25.4 MiB, data loaded,
#   '205/WTrigger5/Critical/1/Unamb/4/Aizkolari honek gaur goizean jokatu du Bilbon/Erg': 1
#   '205/WTrigger5/Critical/10/Unamb/3/Diseinatzaile hau esperantza handiz jaitsi da sariketara/Abs': 1
#   '205/WTrigger5/Critical/100/Amb/1/Abokatu hauek hamaikak aldera hurbildu dira epaitegira/Abs': 1
#   '205/WTrigger5/Critical/101/Unamb/4/Sorgin horrek hiru orduz pentsatu du etxolan/Erg': 1
#   '205/WTrigger5/Critical/102/Unamb/3/Bezero hura denbora luzez ezkutatu da saltokian/Abs': 1
#   '205/WTrigger5/Critical/103/Amb/2/Bitartekari hauek mehatxuen ondorioz deklaratu dute etxetik/Erg': 1
#   '205/WTrigger5/Critical/104/Amb/1/Atleta horiek oraintxe bertan ezkutatu dira harmailetan/Abs': 1
#   '205/WTrigger5/Critical/105/Unamb/4/Aita hark seme-alaben kustodiagatik argudiatu du gaur/Erg': 1
#   '205/WTrigger5/Critical/106/Unamb/3/Kontseilari hau pandemia egoeragatik arduratu da prentsaurrean/Abs': 1
#   '205/WTrigger5/Critical/107/Amb/2/Gitarrista horiek managerrekin batera begiratu dute publikorantz/Erg': 1
#   and 374 more events ...>,
#  '05': <EpochsFIF | 334 events (all good), -0.1 – 1 s (baseline off), ~22.5 MiB, data loaded,
#   '205/WTrigger5/Critical/1/Amb/1/Aizkolari hauek gaur goizean iragan dira Bilbotik/Abs': 1
#   '205/WTrigger5/Critical/10/Unamb/4/Diseinatzaile honek esperantza handiz bozkatu du sariketan/Erg': 1
#   '205/WTrigger5/Critical/100/Amb/2/Abokatu hauek hamaikak aldera deklaratu dute epaitegian/Erg': 1
#   '205/WTrigger5/Critical/101/Amb/1/Sorgin horiek hiru orduz ezkutatu dira etxolan/Abs': 1
#   '205/WTrigger5/Critical/102/Unamb/4/Bezero hark denbora luzez argudiatu du saltokian/Erg': 1
#   '205/WTrigger5/Critical/103/Unamb/3/Bitartekari hau mehatxuen ondorioz ezkutatu da etxean/Abs': 1
#   '205/WTrigger5/Critical/104/Amb/2/Atleta horiek oraintxe bertan begiratu dute harmailarantz/Erg': 1
#   '205/WTrigger5/Critical/105/Amb/1/Aita haiek seme-alaben kustodiagatik arduratu dira gaur/Abs': 1
#   '205/WTrigger5/Critical/106/Unamb/4/Kontseilari honek pandemia egoeragatik deklaratu du prentsaurrean/Erg': 1
#   '205/WTrigger5/Critical/107/Unamb/3/Gitarrista hori managerrekin batera arduratu da publikoaz/Abs': 1
#   and 374 more events ...>,
#  '23': <EpochsFIF | 282 events (all good), -0.1 – 1 s (baseline off), ~19.0 MiB, data loaded,
#   '205/WTrigger5/Critical/1/Unamb/3/Aizkolari hau gaur goizean iragan da Bilbotik/Abs': 1
#   '205/WTrigger5/Critical/10/Amb/2/Diseinatzaile hauek esperantza handiz bozkatu dute sariketan/Erg': 1
#   '205/WTrigger5/Critical/100/Unamb/4/Abokatu honek hamaikak aldera deklaratu du epaitegian/Erg': 1
#   '205/WTrigger5/Critical/101/Unamb/3/Sorgin hori hiru orduz ezkutatu da etxolan/Abs': 1
#   '205/WTrigger5/Critical/102/Amb/2/Bezero haiek denbora luzez argudiatu dute saltokian/Erg': 1
#   '205/WTrigger5/Critical/103/Amb/1/Bitartekari hauek mehatxuen ondorioz ezkutatu dira etxean/Abs': 1
#   '205/WTrigger5/Critical/104/Unamb/4/Atleta horrek oraintxe bertan begiratu du harmailarantz/Erg': 1
#   '205/WTrigger5/Critical/105/Unamb/3/Aita hura seme-alaben kustodiagatik arduratu da gaur/Abs': 1
#   '205/WTrigger5/Critical/106/Amb/2/Kontseilari hauek pandemia egoeragatik deklaratu dute prentsaurrean/Erg': 1
#   '205/WTrigger5/Critical/107/Amb/1/Gitarrista horiek managerrekin batera arduratu dira publikoaz/Abs': 0
#   and 374 more events ...>}

# %%
epochs_interpolated={}
for sub, epochs_object in epochs_autoreject.items():
    epochs_copy=epochs_object.copy()
    epochs_copy=epochs_copy.interpolate_bads(reset_bads=True) #Ya no queremos que los canales estén marcados como dañados
    epochs_interpolated[sub]=epochs_copy
# Out:
# Setting channel interpolation method to {'eeg': 'spline'}.
# Setting channel interpolation method to {'eeg': 'spline'}.
# Setting channel interpolation method to {'eeg': 'spline'}.
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
# /tmp/ipython-input-1437283664.py:4: RuntimeWarning: No bad channels to interpolate. Doing nothing...
#   epochs_copy=epochs_copy.interpolate_bads(reset_bads=True) #Ya no queremos que los canales estén marcados como dañados
# /tmp/ipython-input-1437283664.py:4: RuntimeWarning: No bad channels to interpolate. Doing nothing...
#   epochs_copy=epochs_copy.interpolate_bads(reset_bads=True) #Ya no queremos que los canales estén marcados como dañados
# /tmp/ipython-input-1437283664.py:4: RuntimeWarning: No bad channels to interpolate. Doing nothing...
#   epochs_copy=epochs_copy.interpolate_bads(reset_bads=True) #Ya no queremos que los canales estén marcados como dañados
#     Automatic origin fit: head of radius 96.2 mm
# Computing interpolation matrix from 29 sensor positions
# Interpolating 1 sensors
# Setting channel interpolation method to {'eeg': 'spline'}.
# /tmp/ipython-input-1437283664.py:4: RuntimeWarning: No bad channels to interpolate. Doing nothing...
#   epochs_copy=epochs_copy.interpolate_bads(reset_bads=True) #Ya no queremos que los canales estén marcados como dañados

# %% [markdown]
# Después, corregimos las epochs mediante la técnica de la línea base o `baseline`. Esta técnica, en sí, es muy intuitiva de entender.
#
# <br>
#
# Al examinar potenciales, una de las características que usamos para describirlos es ver si estos son Negativos o Positivos. Sin embargo, ya hemos discutido antes, en la parte de referenciar, lo relativa que puede ser una unidad de medición. Aquí es donde entra el `baseline`.
#
# <br>
#
#
# <center>
#
# Se asume que se quiere estudiar la señal **inducida** por el evento. Entonces, una práctica es restar a esta señal el patrón basal (o por defecto) que tiene el participante, ya que este patrón no se relaciona con el evento específicamente, sino con sus características de sujeto.
#
# Esa señal a restar sería su `baseline`.
#
# </center>
#
# <br>
#
# Es muy importante pensar en qué vamos a considerar como "señal basal". Normalmente, se considera que promediar un intervalo prudente antes del evento puede darnos idea de la actividad por defecto o la no relacionada con el evento; pero esto dependerá bastante de nuestro modelo experimental.

# %%
#@title Ｂｌａｃｋ　Ｂｏｘ＿(Baselines)


# function to draw signal
def draw_potential(t):
    y = 0.2
    y += 0.6 * np.exp(-((t + 0.3) ** 3) / (2 * 0.1 ** 3))   # before 0
    y += -0.8 * np.exp(-((t - 0.3) ** 2) / (2 * 0.08 ** 2)) # after 0
    return y

# function to draw correction. Takes the previous funct
def plot_potential(b_ini, apply_baseline):
    fs = 1000
    t = np.linspace(-0.4, 0.8, int(1.2 * fs))
    y_orig = draw_potential(t)
    y_corr = y_orig.copy()

    # b_ini should be <= 0
    b_ini = -b_ini
    b_ini = min(b_ini, 0)
    mask = (t >= b_ini / 1000) & (t < 0)
    baseline_mean = np.mean(y_corr[mask]) if np.any(mask) else 0.0
    print(f"Promedio de la señal del baseline ({b_ini} a 0 ms): {baseline_mean:.4f} µV")
    if apply_baseline:
        if np.any(mask):
            y_corr -= baseline_mean

    # Select which plot to show
    y_to_plot = y_corr if apply_baseline else y_orig

    # Plot
    fig, ax = plt.subplots(figsize=(8, 3), dpi=150)
    fig.patch.set_facecolor("#0a0f1f")
    ax.set_facecolor("#0a0f1f")

    # Remnant of original signal
    if apply_baseline:
        ax.plot(t * 1000, y_orig, linewidth=1.5, color="#00ffd5", alpha=0.2, label="Original")

    # Actual signal
    ax.plot(t * 1000, y_to_plot, linewidth=2.2, color="#00ffd5", label="Corregida" if apply_baseline else "Original")

    ax.axvline(0, color="#ff6ec7", linestyle="--", linewidth=1)
    ax.axvspan(b_ini, 0, color="#ff6ec7", alpha=0.1)

    ax.set_xlim(-400, 800)
    ax.set_ylim(-1, 1)
    ax.set_xlabel("Tiempo (ms)", color="#cde3ff")
    ax.set_ylabel("Amplitud (µV)", color="#cde3ff")
    ax.set_title(
        f"Señal {'con' if apply_baseline else 'sin'} {f'baseline de {baseline_mean:.2f}µV ({b_ini} a 0 ms)' if apply_baseline else 'baseline (0.2 µV en tiempo 0)'}",
        color="#e6f0ff", pad=10
    )

    for spine in ax.spines.values():
        spine.set_color("#20345c")
        spine.set_linewidth(1.2)

    ax.tick_params(colors="#a8c8ff")
    ax.grid(True, which="both", linewidth=0.6, alpha=0.25)
    ax.legend(loc="upper right", facecolor="#0a0f1f", edgecolor="#20345c",
              labelcolor="#cde3ff", fontsize=8)

    #box
    if np.any(mask):
      ax.text(
          x=-100,  # center
          y=-0.2,
          s=f"Promedio: {baseline_mean:.3f} µV",
          color="#00ffd5",
          ha="center",
          va="center",
          fontsize=7,
          bbox=dict(facecolor="#0a0f1f", boxstyle="round,pad=0.2")
      )
    plt.tight_layout()
    plt.show()

# Widgets
ini_slider = ipywidgets.IntSlider(
    value=0, min=0, max=400, step=10, description='Baseline (ms)'
)

toggle_baseline = ipywidgets.ToggleButtons(
    options=[("Sin aplicar", False), ("Aplicada", True)],
    description="Corrección:",
)

ipywidgets.interactive(plot_potential, b_ini=ini_slider, apply_baseline=toggle_baseline)
# Out:
# interactive(children=(IntSlider(value=0, description='Baseline (ms)', max=400, step=10), ToggleButtons(descrip…

# %% [markdown]
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.apply_baseline</strong>
#   <br><br>Objeto mne.Epochs
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.Epochs.html#mne.Epochs.apply_baseline"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#
#
#   </th></tr>
#
#
#
#
#
#   <tr><th colspan="1">Parámetros</th><th colspan="1" align="left">Descripción</th></tr>
#   <tr><td>baseline</td><td>Recibe un "tuple" de dos valores. El primero es el tiempo mínimo y el segundo el tiempo máximo de la baseline. Forma un intervalo. En nuestro caso (-1.0, 0). Como es "tuple" va entre paréntesis. </td></tr>
#
#   <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
#   <td colspan="2">
#   Objeto tipo mne.Epochs con la corrección de línea base aplicada.
#   </td>
# </table>

# %%
epochs_baseline={}
for sub, epochs_object in epochs_interpolated.items():
    epochs_copy=epochs_object.copy()
    epochs_copy=epochs_copy.apply_baseline((-0.1,0))
    epochs_baseline[sub]=epochs_copy
# Out:
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)

# %% [markdown]
# Ahora que ya tenemos las epochs con baseline e interpoladas, podemos explorarlas. Ya sabemos acceder al objeto mediante el diccionario, pero además, MNE Python nos permite seleccionar las epochs en base a las anotaciones que tiene, de manera parecida a un diccionario.
#
# Probemos escogiendo los eventos que sean `'Critical'`, `'Amb'` y `'Abs'` a la vez. Para esto, podemos utilizar las propiedades del objeto mne.Epochs: Siempre que en las anotaciones originales, una string tenga "/", MNE considerará que ese "/" está separando valores independientes. Así, al llamar al objeto, podemos combinar los valores separados con "/" en las anotaciones, usando de igual forma "/".

# %%
epochs_baseline['01']['Critical/Amb/Abs'].plot_image(picks='Cz')
# Out:
# Not setting metadata
# 29 matching events found
# No baseline correction applied
# 0 projection items activated
# [<Figure size 640x480 with 4 Axes>]

# %% [markdown]
# <h2>Potenciales evocados<h2>
# <br>
#
# Ya sabemos que las epochs son simplemente cortes ¿Cómo hacemos para obtener potenciales evocados?. En MNE-Python, los objetos mne.Evoked se crean a partir del promedio de epochs.
#
# <br>
#
# Esto quiere decir que un objeto evoked es simplemente varios cortes fusionados en uno. Sin embargo, para que tenga lógica, sólo deberíamos juntar los cortes de eventos parecidos entre sí, o que compartan alguna característica que se quiere explorar.
# <br>
#
# En este caso, intentaremos juntar las condiciones `Critical/Amb/Erg`, `Critical/Unamb/Erg`, `Critical/Amb/Abs` y `Critical/Unamb/Abs`. Lo que buscaremos, por tanto, es comparar las respuestas ante el la etiqueta de "Ambigüedad"
#
# <br>
#
# El evoked lo podemos obtener mediante el método `.average()` del objeto Epochs.Con este método, se combinarán las Epochs seleccionadas mediante el promedio de sus valores. Entonces, lo que resultará es que, por cada condición de interés, se seleccionarán las epochs de un participante que cumplan con el criterio de selección y se promediarán. Eso nos llevará a tener un evoked por cada condición, por participante.
#
# <br>
#
# Entonces, lo que tendríamos son evokeds por participantes, pero lo que también se quiere frecuentemente es analizar el efecto a través de todos los participantes. Para ello, deberíamos fusionar los evokeds de todos los participantes, y para esto tenemos el método `mne.grand_average()`, el cual se encarga específicamente de combinar evokeds.
#
# <br>
#
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.average</strong>
#   <br><br>Objeto mne.Epochs
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.Epochs.html#mne.Epochs.average"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#
#
#   </th></tr>
#
#
#
#
#
#
#
#   <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
#   <td colspan="2">
#   Objeto tipo       <a href="https://mne.tools/stable/generated/mne.Evoked.html#mne.Evoked"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       mne.Evoked
#   </a>. Se crea un nuevo objeto a partir de las epochs.
#   </td>
# </table>
#
# <br>
#
#
# <table>
#   <tr><th colspan="2" align="left">Función: <strong>mne.grand_average</strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.grand_average.html#mne.grand_average"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#   <tr><th colspan="1">Parámetros</th><th colspan="1" align="left">Descripción</th></tr>
#
#   </th></tr>
#
#   <tr><td>all_inst</td><td>Recibe una lista con las instancias a promediar. Puede recibir Evokeds, TFR (objetos que han calculado frecuencias), etc. </td></tr>
#
#
#
#
#
#
#   <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
#   <td colspan="2">
#   Retorna el promedio de los objetos brindados en un objeto del mismo tipo. En este caso, como daremos Evokeds, recibiremos otra       <a href="https://mne.tools/stable/generated/mne.Evoked.html#mne.Evoked"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       mne.Evoked
#   </a>.
#   </td>
# </table>

# %%
evokeds_sub={} #Evoked. Primer colapso / fusión de cortes
grand_averages={} #Grand averages. Segundo colapso / fusión de cortes. Juntamos los evokeds.
evokeds_list=[] #Esta es una lista que utilizaremos para guardar los evokeds a los que queremos hacer grand averages.
conditions=['Critical/Amb/Erg', #Definimos las condiciones que queremos. Recordemos que tenemos el atributo "Slice" en las epochs.
           'Critical/Amb/Abs',
           'Critical/Unamb/Erg',
           'Critical/Unamb/Abs']

for condition in conditions:
    for sub, epochs in epochs_baseline.items():
        epochs_copy=epochs.copy()#Copiamos por buena práctica
        epochs_copy=epochs_copy[condition].copy()
        evoked=epochs_copy.average() #Evoked
        if sub not in evokeds_sub:
            evokeds_sub[sub]={}
        evokeds_sub[sub][condition]=evoked
        evokeds_list.append(evoked) #guardamos todas las evoked de una sola condición en la lista.
    grand_averages[condition]=mne.grand_average(evokeds_list) #grand average
    evokeds_list.clear() #limpiamos la lista para no mezclarla con la próxima condición (que viene en la siguiente iteración del loop)
# Out:
# Identifying common channels ...
# Identifying common channels ...
# Identifying common channels ...
# Identifying common channels ...

# %%
display(evokeds_sub['01'].keys())
grand_averages
# Out:
# dict_keys(['Critical/Amb/Erg', 'Critical/Amb/Abs', 'Critical/Unamb/Erg', 'Critical/Unamb/Abs'])
# {'Critical/Amb/Erg': <Evoked | 'Grand average (n = 5)' (average, N=5), -0.1 – 1 s, baseline -0.1 – 0 s, 30 ch, ~106 KiB>,
#  'Critical/Amb/Abs': <Evoked | 'Grand average (n = 5)' (average, N=5), -0.1 – 1 s, baseline -0.1 – 0 s, 30 ch, ~106 KiB>,
#  'Critical/Unamb/Erg': <Evoked | 'Grand average (n = 5)' (average, N=5), -0.1 – 1 s, baseline -0.1 – 0 s, 30 ch, ~106 KiB>,
#  'Critical/Unamb/Abs': <Evoked | 'Grand average (n = 5)' (average, N=5), -0.1 – 1 s, baseline -0.1 – 0 s, 30 ch, ~106 KiB>}

# %% [markdown]
# <h2>Evokeds y Grand Averages<h2>
#
# <br>
#
# Por conveniencia, los llamaremos distinto, aunque ya sabemos que son el mismo tipo de objeto; lo cual quiere decir que tienen los mismos métodos y atributos. Podemos empezar ploteando una representación visual de un grand_average mediante el método `.plot_joint`.
#
# <br>
#
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.plot_joint</strong>
#   </strong>
#   <br>
#   <br>
#   Objeto mne.Evoked
#       <a href="https://mne.tools/stable/generated/mne.Evoked.html#mne.Evoked.plot_joint"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#
#
#   </th></tr>
#   <tr><th colspan="1">Parámetros</th><th colspan="1" align="left">Descripción</th></tr>
#   <tr><td>picks</td><td>Recibe una lista de strings con los nombres de los canales. Por default, grafica todos, pero esta vez seleccionaremos unos cuantos. </td></tr>
#
#
#
#
#
#
#   <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
#   <td colspan="2">
#   Objeto de matplotlib <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       Figure
#   </a>. Es decir, un gráfico.
#   </td>
# </table>

# %%
graph1=grand_averages['Critical/Amb/Erg'].plot_joint(
    picks=['Fz','Cz','C3', 'C4', 'Pz']
    )
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.

# %% [markdown]
# Otra función útil cuando tenemos grand_averages por cada condición es `mne.viz.plot_compare_evokeds`. Esta visualización nos permite comparar dos evokeds en un solo gráfico. Como nosotros nuestros promedios de todos los participantes se han guardado en grand_averages (evokeds), podemos comparar en base a dichos objetos.
#
# <br>
#
# <table>
#   <tr><th colspan="2" align="left">Función: <strong>mne.viz.plot_compare_evokeds</strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.viz.plot_compare_evokeds.html#mne.viz.plot_compare_evokeds"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#
#
#   </th></tr>
#   <tr><th colspan="1">Parámetros</th><th colspan="1" align="left">Descripción</th></tr>
#   <tr><td>evokeds</td><td>Recibe una lista con los evokeds a comparar o un diccionario con forma {"Nombre de la condición": objeto evoked}. En este caso, utilizaremos el diccionario para etiquetar condiciones. </td></tr>
#   <tr><td>picks</td><td>Lista de canales cuya señal queremos plotear. Si son varios, se tiene que calcular una estimación (como la 'mean'). </td></tr>
#   <tr><td>show_sensors</td><td>True or False para mostrar la imagen del montaje con el electrodo elegido. </td></tr>
#   <tr><td>title</td><td>String para ponerle el título que queramos a la figura. </td></tr>
#   <tr><td>truncate_xaxis</td><td> Parámetro de estilo para agregar el eje x de la plot. Si se ignora, es "False", pero escogeremos "True". </td></tr>
#   <tr><td>truncate_yaxis</td><td> Parámetro de estilo para agregar el eje y de la plot. Si se ignora, es "False", pero escogeremos "True". </td></tr>
#   <tr><td>axes</td><td>Guardar la figura en un gráfico más grande de matplotlib. Lo utilizaremos para después sombrearla. Si se ignora es None. No afecta en la visualización. </td></tr>
#   <tr><td>show</td><td>True or False. Por default, en colab siempre se muestra aunque esté en "False". Sin embargo, si no está en "False" se mostrará dos veces. </td></tr>
#
#   <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
#   <td colspan="2">
#   Lista de figuras de objetos de matplotlib <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       Figure
#   </a>. Es decir, gráficos.
#   </td>
# </table>

# %%
# Creamos nuestro diccionario primero
ambiguous_ergs={
    'Amb/Erg': grand_averages['Critical/Amb/Erg'],
    'Unamb/Erg': grand_averages['Critical/Unamb/Erg']
}

fig, ax = plt.subplots(figsize=(10,7)) #creamos una figura de matplot lib para guardar el gráfico.
#No es necesario, pero lo usaremos para sombrear.


mne.viz.plot_compare_evokeds(evokeds=ambiguous_ergs,
                             picks=['Cz'],
                             #combine='mean', #Si se agregan más electrodos, descomentar.
                             truncate_yaxis=False,
                             truncate_xaxis=False,
                             axes=ax,
                             title='Comparación de condiciones en Cz',
                             show_sensors='upper right',
                             show=False
                             )

#Agregamos un sombreado en el intervalo del N400.
#"ax" es donde está nuestra figura.
ax.axvspan(0.300, 0.500, color='gray', alpha=0.2, zorder=0)

# %% [markdown]
# Otra visualización que se suele usar es el `topomap`. Muestra la topografía de los sensores y un mapa de calor respecto a su activación. Para hacer un topomap, basta con llamar al método `.plot_topomap` del objeto evoked.
#
# <br>
#
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.plot_topomap</strong>
#   </strong><br><br>
#   Objeto mne.Evoked
#       <a href="https://mne.tools/stable/generated/mne.Evoked.html#mne.Evoked.plot_topomap"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#
#
#   </th></tr>
#   <tr><th colspan="1">Parámetros</th><th colspan="1" align="left">Descripción</th></tr>
#   <tr><td>times</td><td>Puede ser un único número o array de números (se ponen entre paréntesis). Si se pasa más de un tiempo, se crea una topografía por tiempo elegido. </td></tr>
#   <tr><td>average</td><td>El topomap estima cómo es la activación en un umbral de tiempo alrededor del "times" elegido. Este parámetro señala la amplitud de ese umbral. </td></tr>
#   <tr><td>ch_types</td><td>En nuestro caso 'eeg'. </td></tr>
#   <tr><td>size</td><td>Tamaño del gráfico. En nuestro caso 2. </td></tr>
#
#   <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
#   <td colspan="2">
#   Objeto de matplotlib <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       Figure
#   </a>. Es decir, gráfico.
#   </td>
# </table>

# %%
graph1=grand_averages['Critical/Amb/Erg'].plot_topomap(times=0.40,
                                                average=0.2,
                                                ch_type='eeg',
                                                size=2
                                                )
                                                # Con estos parámetros intentamos explorar el intervalo del N400
# Out:
# <MNEFigure size 300x355 with 2 Axes>

# %%
grand_averages
# Out:
# {'Critical/Amb/Erg': <Evoked | 'Grand average (n = 5)' (average, N=5), -0.1 – 1 s, baseline -0.1 – 0 s, 30 ch, ~106 KiB>,
#  'Critical/Amb/Abs': <Evoked | 'Grand average (n = 5)' (average, N=5), -0.1 – 1 s, baseline -0.1 – 0 s, 30 ch, ~106 KiB>,
#  'Critical/Unamb/Erg': <Evoked | 'Grand average (n = 5)' (average, N=5), -0.1 – 1 s, baseline -0.1 – 0 s, 30 ch, ~106 KiB>,
#  'Critical/Unamb/Abs': <Evoked | 'Grand average (n = 5)' (average, N=5), -0.1 – 1 s, baseline -0.1 – 0 s, 30 ch, ~106 KiB>}

# %%
#@title Ｂｌａｃｋ　Ｂｏｘ (＞Ｅｘｐｌｏｒｅ)
def plot_topomap(condition, times, average):
    obj = grand_averages[condition]
    obj.plot_topomap(
        times=times,
        average=average,
        ch_type='eeg',
        size=4,
        res=128,
        vlim=(-2,2)
        )
toggle_condition=ipywidgets.ToggleButtons(
    options=['Critical/Amb/Erg', 'Critical/Amb/Abs', 'Critical/Unamb/Erg', 'Critical/Unamb/Abs'],
    description='Condición:',
    disabled=False,
    button_style='',
    style={'button_width':'10em'},
)
label = ipywidgets.HTML(
    value="<div style='font-size:18px; text-align:left;'>Exploremos qué sucede en cada condición:</div>"
)
ini_slider = ipywidgets.FloatSlider(
    value=0, min=0, max=1, step=0.05, description='Tiempo (ms)'
)

ave_slider = ipywidgets.FloatSlider(
    value=0.1, min=0.01, max=1, step=0.05, description='Umbral (ms)'
)

plot_widget = ipywidgets.interactive(
    plot_topomap,
    condition=toggle_condition,
    times=ini_slider,
    average=ave_slider
)

ipywidgets.VBox([label, plot_widget])
# Out:
# VBox(children=(HTML(value="<div style='font-size:18px; text-align:left;'>Exploremos qué sucede en cada condici…

# %% [markdown]
# <h2>Obtener datos de los objetos<h2>
#
#
# Adicionalmente, podemos obtener los datos de cualquier objeto evoked o epoch con el método `.to_data_frame` Esto es sumamente necesario para realizar comparaciones estadísticas. Los datos se devuelven en una tabla de pandas.
#
#
#
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.to_data_frame</strong></strong>
#   </strong>
#   <br><br>
#   Objeto mne.Evoked</strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.Evoked.html#mne.Evoked.to_data_frame"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#
#
#   </th></tr>
#
# <br>
#
#
# <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
# <td colspan="2">
# Tabla de pandas dataframe.
# </table>

# %%
dataframe=evokeds_sub['01']['Critical/Amb/Erg'].to_data_frame()
dataframe
# Out:
#       time       Fp1       Fp2        F7        F3        Fz        F4  \
# 0   -0.100  0.482176  0.321461  0.574696  0.542849  1.200865  0.429074
# 1   -0.096  0.199175  0.173064  0.478995  0.217606  0.933303  0.260425
# 2   -0.092 -0.037440  0.028529  0.126042 -0.041478  0.667857  0.177103
# 3   -0.088 -0.200734 -0.113115 -0.294585 -0.125204  0.483067  0.168289
# 4   -0.084 -0.277949 -0.240432 -0.549764  0.035639  0.406165  0.186450
# ..     ...       ...       ...       ...       ...       ...       ...
# 271  0.984 -1.452377 -1.358751 -0.970375 -1.075992 -4.989860 -2.208945
# 272  0.988 -0.895390 -1.056756 -0.617493 -0.741207 -4.706221 -2.060720
# 273  0.992 -0.362809 -0.650049 -0.238820 -0.408858 -4.182908 -1.819603
# 274  0.996 -0.087129 -0.359702 -0.000404 -0.110478 -3.505652 -1.523764
# 275  1.000 -0.069160 -0.249766  0.095013  0.225282 -2.791906 -1.202626
#
#            F8       FC5       FC1  ...       CP6        P7        P3  \
# 0    0.307062  0.237299  0.707296  ... -0.874008 -0.494966 -0.731237
# 1    0.214626  0.261343  0.358719  ... -0.701426 -0.520556 -0.275245
# 2    0.156533  0.079412  0.012480  ... -0.413851 -0.627453  0.099139
# 3    0.154792 -0.157879 -0.137987  ... -0.290762 -0.735707  0.327058
# 4    0.177054 -0.244239 -0.026283  ... -0.376021 -0.897675  0.428802
# ..        ...       ...       ...  ...       ...       ...       ...
# 271 -1.194983 -0.602621 -3.110899  ...  1.027215 -1.366661  4.148611
# 272 -1.379431 -0.315081 -3.012124  ...  0.327166 -1.791992  3.965279
# 273 -1.532177  0.043976 -2.662108  ... -0.543413 -2.594324  3.786407
# 274 -1.458118  0.267639 -2.132383  ... -1.006564 -3.527247  3.489842
# 275 -1.094664  0.241627 -1.524717  ... -0.908081 -4.449565  2.941447
#
#            Pz        P4        P8        O1        Oz        O2      TP10
# 0   -0.247391  0.012392 -0.375705 -0.929214 -0.351305 -0.169844 -0.032689
# 1    0.027158 -0.023377 -0.541244 -0.638217  0.044472 -0.063817 -0.085426
# 2    0.343578  0.142749 -0.548007 -0.334035  0.444563  0.077750 -0.062540
# 3    0.550663  0.451814 -0.526798  0.050518  0.763071  0.189607  0.019592
# 4    0.546340  0.777863 -0.573878  0.430721  0.873200  0.198262  0.128093
# ..        ...       ...       ...       ...       ...       ...       ...
# 271  1.929768  5.516185  1.745352  6.058139  4.161156  2.227720  0.003058
# 272  2.046064  5.180754  0.940168  5.444774  3.813074  1.827726  0.011262
# 273  2.142842  4.787675  0.006765  4.565217  3.392548  1.376894  0.018626
# 274  2.165422  4.421032 -0.660034  3.603881  2.976952  1.062836  0.053100
# 275  2.104134  4.087194 -0.954469  2.722468  2.587827  0.946292  0.135536
#
# [276 rows x 31 columns]

# %% [markdown]
# <h2>Frecuencias de onda<h2>
#
# <br>
#
# Otro de los análisis comunes son los relacionados a las frecuencias de onda o bandas alfa, beta, etc. Lo primero para adentrarnos en el tema es entender que ya no nos referimos a la amplitud (µV), sino a la frecuencia (Hz).
#
# <br>
#
# La lógica de los cortes que hemos aprendido con los evokeds y epochs es transferible. Al final, no están cambiando la señal; sólo midiendo momentos que contienen información de interés.
#
# <br>
#
# ¿Cuál es esa información? En el paradigma de ERP, está relacionada a la amplitud. En el paradigma de frecuencias, está relacionada a Hz.
#
# <br>
#
# Probemos accediendo a nuestro objeto evoked `grand_averages['Critical/Amb/Abs']`. Este tiene una propiedad que es `.compute_psd`, la cual calculará las frecuencias de onda y la actividad en cada una. La intensidad de actividad en una frecuencia el nombre de `power` y se relaciona con la amplitud en la medida de que el power es `V²/Hz`.
#
#
# <br>
#
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.compute_psd</strong></strong>
#   </strong>
#   <br><br>
#   Objeto mne.Evoked</strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.Evoked.html#mne.Evoked.compute_psd"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#
# <br>
# <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
# <td colspan="2">
# Objeto tipo       <a href="https://mne.tools/stable/generated/mne.time_frequency.Spectrum.html#mne.time_frequency.Spectrum"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       Spectrum</a>. Es el objeto después de computar el Power Spectral Density.
# </table>
#
# <br>
#
# Al crear nuestro objeto Spectrum, también podemos llamar métodos familiares como `.plot_topomap` o `.plot`. El primer método nos dará una topografía en donde veremos la distribución en nuestro montaje del poder de la señal en las distintas bandas que se han relacionado con señales del cerebro.
#
# <br>
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.plot_topomap</strong></strong>
#   </strong>
#   <br><br>
#   Objeto mne.Spectrum</strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.time_frequency.Spectrum.html#mne.time_frequency.Spectrum.plot_topomap"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
# </th></tr>
# <tr><td>dB</td><td>True or False. Determina si plotear las unidades de medida de decibeles o no. </td></tr>
#
# <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
# <td colspan="2">
#   Objeto de matplotlib <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       Figure
#   </a>. Es decir, gráfico.
#   </td>
# </table>
# <br>
#
# Por otra parte `.plot` nos dará una figura en donde veremos el poder total de cada una de las bandas.
#
# <br>
#
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.plot</strong></strong>
#   </strong>
#   <br><br>
#   Objeto mne.Spectrum</strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.time_frequency.Spectrum.html#mne.time_frequency.Spectrum.plot"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
# </th></tr>
# <tr><td>axes</td><td>Utilizaremos esto para colocarlo en una figura matplotlib y reducir el límite del eje y. </td></tr>
#
# <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
# <td colspan="2">
#   Objeto de matplotlib <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       Figure
#   </a>. Es decir, gráfico.
#   </td>
# </table>

# %%
spectrum=grand_averages['Critical/Amb/Erg'].compute_psd() #Nuestro objeto evoked. Calculamos el PSD y lo guardamos en 'spectrum'
graph1=spectrum.plot_topomap(dB=True)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows

# %%
fig, ax = plt.subplots(figsize=(10,7))
spectrum.plot(axes=ax)
ax.set_xlim(0,60)
# Out:
# Plotting power spectral density (dB=True).
# (0.0, 60.0)

# %% [markdown]
# <h2>Explorar los cambios de en las frecuencias durante el tiempo<h2>
#
# En el paper que estamos usando de base, una hipótesis consistía en ver el cambio de ciertas frecuencias en el tiempo. Es decir, cómo las frecuencias cambiaban alrededor del evento. Para eso, tenemos que computar la representación tiempo-frecuencia (TFR).
#
# <br>
#
# Nosotros ya hemos segmentado la data en Epochs y Evokeds. Es decir, tenemos los tiempos que nos importan y la data alrededor de ellos. En este sentido, podemos calcular la TFR a partir de estos objetos, con el método `.compute_tfr`. En esta ocasión, computaremos la TFR a partir de los evokeds.
#
# <br>
#
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.compute_tfr</strong></strong>
#   </strong>
#   <br><br>
#   Objeto mne.Evoked</strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.Evoked.html#mne.Evoked.compute_tfr"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
# </th></tr>
# <tr><td>method</td><td>El método para computar las TFR. Por simpleza, seleccionaremos "morlet".  </td></tr>
# <tr><td>freqs</td><td>Información sobre el rango de frecuencias que queremos obtener en el cálculo. Tiene forma de array (fmínima, fmáxima, salto entre frecuencias). Por ejemplo, de 1 a 2Hz, con un salto de 0.5, obtendríamos: 1, 1.5, 2. </td></tr>
# <tr><td>picks</td><td>Canales de datos a tomar en cuenta en el cálculo. "eeg" en nuestro caso. </td></tr>
# <tr><td>output</td><td>La magnitud que queremos calcular. En nuestro caso es "power". </td></tr>
# <tr><td>n_cycles</td><td>¿Cuántas oscilaciones por frecuencia tendrán que ver nuestras ventanas? En nuestro caso: 3. Valores más altos amplían la ventana (distingue mejor entre frecuencias), pero pierde precisión de cuándo ocurre un cambio. </td></tr>
# <tr><td>decim</td><td>Luego del cálculo TFR, podemos elegir cuántas muestras del cálculo queremos como retorno. decim=1 es 1/samplingfreq (1/250Hz). Con 12, nuestro output dibujará un nuevo dato cada 50ms aproximadamente. </td></tr>
# <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
# <td colspan="2">
#   Objeto AverageTFR <a href="https://mne.tools/stable/generated/mne.time_frequency.AverageTFR.html#mne.time_frequency.AverageTFR"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       mne.time_frequency.AverageTFR
#   </a>. Es un objeto con información de la transformación a tiempo-frecuencia.
#   </td>
# </table>

# %%
frequencies = np.arange(4.5, 40, 0.5)
tfr_subs={}
conditions=['Critical/Amb/Erg',
           'Critical/Amb/Abs',
           'Critical/Unamb/Erg',
           'Critical/Unamb/Abs']

for condition in conditions:
    for sub in evokeds_sub.keys(): #Ojo que estamos ahora iterando en las keys. Dentro de cada key hay un diccionario.
        tfr=evokeds_sub[sub][condition].copy()
        tfr=tfr.compute_tfr(
                            method='morlet',
                            freqs=frequencies,
                            picks='eeg',
                            output='power',
                            n_cycles=3, #cuantos siglos quiero ver por frecuencia.
                            decim=12 #cuantos puntos quiero de salida. 1/250Hz es 4ms. decim=1 es un punto de la señal, o sea 4ms.
                            )
        if sub not in tfr_subs:
            tfr_subs[sub]={}
        tfr_subs[sub][condition]=tfr

# %%
tfr_subs
# Out:
# {'01': {'Critical/Amb/Erg': <Power Estimates from Evoked (nave=30), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Amb/Abs': <Power Estimates from Evoked (nave=29), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Unamb/Erg': <Power Estimates from Evoked (nave=33), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Unamb/Abs': <Power Estimates from Evoked (nave=30), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>},
#  '02': {'Critical/Amb/Erg': <Power Estimates from Evoked (nave=40), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Amb/Abs': <Power Estimates from Evoked (nave=39), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Unamb/Erg': <Power Estimates from Evoked (nave=37), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Unamb/Abs': <Power Estimates from Evoked (nave=33), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>},
#  '04': {'Critical/Amb/Erg': <Power Estimates from Evoked (nave=46), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Amb/Abs': <Power Estimates from Evoked (nave=48), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Unamb/Erg': <Power Estimates from Evoked (nave=48), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Unamb/Abs': <Power Estimates from Evoked (nave=47), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>},
#  '05': {'Critical/Amb/Erg': <Power Estimates from Evoked (nave=39), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Amb/Abs': <Power Estimates from Evoked (nave=42), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Unamb/Erg': <Power Estimates from Evoked (nave=41), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Unamb/Abs': <Power Estimates from Evoked (nave=43), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>},
#  '23': {'Critical/Amb/Erg': <Power Estimates from Evoked (nave=38), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Amb/Abs': <Power Estimates from Evoked (nave=36), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Unamb/Erg': <Power Estimates from Evoked (nave=36), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#   'Critical/Unamb/Abs': <Power Estimates from Evoked (nave=36), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>}}

# %% [markdown]
# <br>
#
#
# Como hemos sacado un TFR de nuestro Evoked, tenemos la frecuencia fase-bloqueada.
#
# <br>
#
# <center>
#
# *¿Cómo que fase-bloqueada, profe? ¡¿Por qué se inventa palabras y espera que entienda?!*
#
# </center>
#
# <br>
#
# ¡Achachay! ¡Qué buena pregunta! Pero esa es una caja negra para otra historia. Lo que nos servirá saber por ahora es que el que esté fase-bloqueadas nos sirve para ver las frecuencias relacionadas a los eventos (ERF).
#
# <br>
#
# Para esto, tendremos que seguir pasos parecidos a los de el paradigma ERP. Antes de promediar entre todos los sujetos, debemos aplicar un `baseline`. Recordemos que en el paradigma ERP, el baseline era el promedio en la amplitud, pero ahora estamos analizando frecuencias: **el baseline de frecuencias es distinto al baseline de amplitud**.
#
# <br>
#
# El objetivo es el mismo, pero los valores que nos importan son otros. Esta vez nos ayudaremos de nuevo del método `.apply_baseline`, que también existe en los objetos `AverageTFR`.
#
# <br>
#
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.apply_baseline</strong></strong>
#   </strong>
#   <br><br>
#   Objeto mne.time_frequency.AverageTFR</strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.time_frequency.AverageTFR.html#mne.time_frequency.AverageTFR.apply_baseline"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#   <tr><th colspan="1">Parámetros</th><th colspan="1" align="left">Descripción</th></tr>
# </th></tr>
# <tr><td>baseline</td><td>De nuevo una tupla. Esta vez es la tupla de la frecuencia mínima y la máxima. En nuestro caso utilizaremos la longitud previa de nuestra evoked (-0.1, 0)  </td></tr>
# <tr><td>mode</td><td>En el paradigma ERP, es por defecto "mean" para el promedio de los valores. Como en TFR tenemos "potencias" por frecuencias, los cálculos son más complejos. Utilizaremos "logratio".  </td></tr>
# <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
# <td colspan="2">
#   Objeto AverageTFR <a href="https://mne.tools/stable/generated/mne.time_frequency.AverageTFR.html#mne.time_frequency.AverageTFR"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       mne.time_frequency.AverageTFR
#   </a>. El objeto con la corrección realizada.
#   </td>
# </table>
#
# <br>
#
#
# Finalmente promediamos todos los AverageTFR que tenemos, así como hicimos con los objetos Evokeds. Recordemos cuando revisamos la función `mne.grand_average` pudimos ver que recibe varios tipos de objetos. Esta la función que utilizaremos de nuevo.
#
#
# <br>
#
#
# <table>
#   <tr><th colspan="2" align="left">Función: <strong>mne.grand_average</strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.grand_average.html#mne.grand_average"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
#   <tr><th colspan="1">Parámetros</th><th colspan="1" align="left">Descripción</th></tr>
#
#   </th></tr>
#
#   <tr><td>all_inst</td><td>Recibe una lista con las instancias a promediar. Puede recibir Evokeds, TFR (objetos que han calculado frecuencias), etc. </td></tr>
#
#
#
#
#
#
#   <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
#   <td colspan="2">
#   Retorna el promedio de los objetos brindados en un objeto del mismo tipo. En este caso daremos y recibiremos       <a href="https://mne.tools/stable/generated/mne.time_frequency.AverageTFR.html#mne.time_frequency.AverageTFR"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       mne.time_frequency.AverageTFR
#   </a>.
#   </td>
# </table>

# %%
tfr_grand_averages={}
tfr_list_to_average=[]
conditions=['Critical/Amb/Erg',
           'Critical/Amb/Abs',
           'Critical/Unamb/Erg',
           'Critical/Unamb/Abs']


for condition in conditions:
  for sub in tfr_subs.keys():
    tfr_object=tfr_subs[sub][condition].copy()
    tfr_object=tfr_object.apply_baseline(baseline=(-0.1, -0.0), mode='logratio')
    tfr_list_to_average.append(tfr_object)
  subs_tfr_average=mne.grand_average(tfr_list_to_average)
  tfr_grand_averages[condition]=subs_tfr_average
  tfr_list_to_average.clear()
# Out:
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Identifying common channels ...
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Identifying common channels ...
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Identifying common channels ...
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Identifying common channels ...

# %%
tfr_grand_averages
# Out:
# {'Critical/Amb/Erg': <Power Estimates from Evoked (nave=5), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#  'Critical/Amb/Abs': <Power Estimates from Evoked (nave=5), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#  'Critical/Unamb/Erg': <Power Estimates from Evoked (nave=5), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>,
#  'Critical/Unamb/Abs': <Power Estimates from Evoked (nave=5), morlet method | 30 channels × 71 freqs × 23 times, 4.5 - 39.5 Hz, -0.10 - 0.96 s, 424 KiB>}

# %% [markdown]
# <h2>Visualizar frecuencias<h2>
#
# <br>
#
# Con todos los cálculos hechos, podemos explorar las frecuencias a través del tiempo con métodos parecidos a los objetos evokeds. Exploraremos `.plot` y `.plot_topomap`.
#
# <br>
#
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.plot</strong></strong>
#   </strong>
#   <br><br>
#   Objeto mne.time_frequency.AverageTFR</strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.time_frequency.AverageTFR.html#mne.time_frequency.AverageTFR.plot"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
# </th></tr>
# <tr><td>combine</td><td>Combina los datos de los canales ya normalizados y pasados por baseline. Si ignoramos este parámetro, MNE nos dará una plot por canal(electrodo). Le daremos por ahora "mean" para visualizar.</td></tr>
# <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
#
# <td colspan="2">
#   Lista de objetos de matplotlib <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       Figure
#   </a>. Es decir, gráficos.
#   </td>
# </table>
#
#
# <br>
#
# <br>
#
# <table>
#   <tr><th colspan="2" align="left">Método: <strong>.plot_topomap</strong></strong>
#   </strong>
#   <br><br>
#   Objeto mne.time_frequency.AverageTFR</strong>
#   </strong>
#       <a href="https://mne.tools/stable/generated/mne.time_frequency.AverageTFR.html#mne.time_frequency.AverageTFR.plot_topomap"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       [docs]
#   </a>
# </th></tr>
# <tr><td>tmin</td><td>Tiempo desde el cual queremos empezar a visualizar. Se promediará lo encontrado desde este tiempo hasta el tmax.</td></tr>
# <tr><td>tmax</td><td>Tiempo máximo hasta el cual considerar la estimación de poder. Junto con tmin, cortan un intervalo</td></tr>
# <tr><td>fmin</td><td>Frecuencia mínima desde la cual se quieren promediar los datos.</td></tr>
# <tr><td>fmax</td><td>Frecuencia máxima hasta la que se quieren promediar los datos.</td></tr>
# <tr><td>cbar_fmt</td><td>Parámetro de la barra de color de la topografía. Determina cuántos decimales mostrar. Para legibilidad colocaremos '%.2f' para tener máximo dos decimales.</td></tr>
# <tr><td>size</td><td>Tamaño de la topografía. En nuestro caso, probemos con 4.</td></tr>
#
#
#
# <tr><th colspan="2" align="left">Objetos que retorna:</th></tr>
# <td colspan="2">
#   Objeto de matplotlib <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure"
#        target="_blank" rel="noopener" style="margin-left:.5rem; font-weight:normal;">
#       Figure
#   </a>. Un gráfico.
#   </td>
# </table>

# %%
graph1=tfr_grand_averages['Critical/Amb/Erg'].plot(
                                                   tmin=-0.1,
                                                   tmax=1,
                                                   combine='mean'
                                                   )
# Out:
# No baseline correction applied

# %%
graph1=tfr_grand_averages['Critical/Amb/Erg'].plot_topomap(
    tmin=0.35,
    tmax=0.45,
    fmin=8,
    fmax=12,
    vlim=(-1.0, 1.0),
    cbar_fmt='%.2f',
    size=4
    )
# Out:
# No baseline correction applied

# %%
graph1=tfr_grand_averages['Critical/Amb/Erg'].plot_topomap(
    tmin=0.3,
    tmax=0.45,
    fmin=15,
    fmax=20,
    vlim=(-1.0, 1.0),
    cbar_fmt='%.2f',
    size=5
    )

# %%
toggle_color.value
# Out:
# 'hsv'

# %%
#@title Ｂｌａｃｋ　Ｂｏｘ (＞Ｅｘｐｌｏｒｅ)


def plot_topomaptfr(condition, tmin, tmax, fmin, fmax, cmap):
    show_names=False


    if toggle_color.value == 'gnuplot2':
      show_names=True
    else:
      show_names=False
    obj = tfr_grand_averages[condition]
    obj.plot_topomap(
        tmin=tmin,
        tmax=tmax,
        fmin=fmin,
        fmax=fmax,
        size=5,
        res=260,
        vlim=(-1,1),
        cbar_fmt='%.2f',
        cmap=cmap,
        show_names=show_names
        )
toggle_condition=ipywidgets.ToggleButtons(
    options=['Critical/Amb/Erg', 'Critical/Amb/Abs', 'Critical/Unamb/Erg', 'Critical/Unamb/Abs'],
    description='Condición:',
    disabled=False,
    button_style='',
    style={'button_width':'10em'},
)
label = ipywidgets.HTML(
    value="<div style='font-size:18px; text-align:left;'>Exploremos qué sucede en cada condición:</div>"
)
t0 = ipywidgets.FloatSlider(
    value=0,    # (inicio, fin)
    min=0.0,
    max=1.0,
    step=0.01,
    description='Tiempo (s)',   # ojo con la unidad
    #readout_format='.2f',
    continuous_update=False,
)
t1 = ipywidgets.FloatSlider(
    value=0.2,    # (inicio, fin)
    min=0.0,
    max=1.0,
    step=0.01,
    description='Tiempo (s)',   # ojo con la unidad
    #readout_format='.2f',
    continuous_update=False,
)

f0_slider = ipywidgets.FloatSlider(
    value=12, min=5, max=40, step=0.05, description='Frecuencia mínima (Hz)'
)

f1_slider = ipywidgets.FloatSlider(
    value=20, min=7, max=40, step=0.05, description='Frecuencia máxima (Hz)'
)


toggle_color=ipywidgets.ToggleButtons(
    options=[
        ('ｄｅｆａｕｌｔ', 'RdBu_r'),
        ('ｏｒ', 'seismic'),
        ('ｓｅｅ','hsv'),
        ('ＦＵＲＴＨＥＲ','gnuplot2'),
        ],
    description='？？:',
    disabled=False,
    button_style='',
    style={'button_width':'10em'},
)



plot_widget = ipywidgets.interactive(
    plot_topomaptfr,
    condition=toggle_condition,
    tmin=t0,
    tmax=t1,
    fmin=f0_slider,
    fmax=f1_slider,
    cmap=toggle_color,
)



ipywidgets.VBox([label, plot_widget])
# Out:
# VBox(children=(HTML(value="<div style='font-size:18px; text-align:left;'>Exploremos qué sucede en cada condici…

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# Ｆｅｌｉｃｉｄａｄｅｓ！
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# Ｙ　ｍｕｃｈａｓ　ｇｒａｃｉａｓ。
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# **Referencias:**
#
# Isasi-Isasmendi, A., Sauppe, S., Andrews, C., Laka, I., Meyer, M., & Bickel, B. (2024). Incremental sentence processing is guided by a preference for agents: EEG evidence from Basque. Language, Cognition and Neuroscience, 39(1), 76-97.
#
# Jas, M., Engemann, D. A., Bekhti, Y., Raimondo, F., & Gramfort, A. (2017). Autoreject: Automated artifact rejection for MEG and EEG data. NeuroImage, 159, 417-429.
#
#
# Jas, M., Engemann, D., Raimondo, F., Bekhti, Y., & Gramfort, A. (2016, June). Automated rejection and repair of bad trials in MEG/EEG. In 2016 international workshop on pattern recognition in neuroimaging (PRNI) (pp. 1-4). IEEE.
#
#
# Gramfort, A., Luessi, M., Larson, E., Engemann, D. A., Strohmeier, D., Brodbeck, C., ... & Hämäläinen, M. (2013). MEG and EEG data analysis with MNE-Python. Frontiers in Neuroinformatics, 7, 267.
# [![DOI](https://zenodo.org/badge/DOI/10.5281/zenodo.17345411.svg)](https://doi.org/10.5281/zenodo.17345411)

# %% [markdown]
# Ａｕｔｏｒ：
#
# Ｙｏ．
